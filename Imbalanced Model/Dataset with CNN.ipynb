# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.3-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 7.4 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.3

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 26.9 MB/s
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.35.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Installing collected packages: tf-estimator-nightly
# Successfully installed tf-estimator-nightly-2.8.0.dev2021122109

# %%
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
import nltk
import unidecode
import re
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
# from keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Bidirectional, Embedding, Dropout, GlobalMaxPooling1D
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.callbacks import ModelCheckpoint

# %%
from keras.layers import Flatten

# %%
def load_dataset(filename):
    df = pd.read_csv(filename)
    print(df.head())
    intent = df["tags"]
    unique_intent = list(set(intent))
    sentences = list(df["patterns"])
  
    return (intent, unique_intent, sentences)

# %%
intent, unique_intent, sentences = load_dataset("intent - intent.csv")
# Out:
#             patterns                                           response  \
# 0                 Hi  ['Hello Human', 'Good To See You Again', 'Hey,...
# 1        How are you  ['Hello Human', 'Good To See You Again', 'Hey,...
# 2        How you are  ['Hello Human', 'Good To See You Again', 'Hey,...
# 3  anyone Present Is  ['Hello Human', 'Good To See You Again', 'Hey,...
# 4  anyone Is Present  ['Hello Human', 'Good To See You Again', 'Hey,...
#
#         tags
# 0  greetings
# 1  greetings
# 2  greetings
# 3  greetings
# 4  greetings

# %%
print(*sentences[:40], sep = "\n")
# Out:
# Hi
# How are you
# How you are
# anyone Present Is
# anyone Is Present
# Good Day
# up Whats
# How Do You do
# do Do You How
# Do do You How
# How Do do You
# Hey
# Hello
# Greetings
# Goodbye
# Again See you
# See you Again
# Ciao
# Hasta Vista La
# Hasta La Vista
# Au Revior
# am I Leaving
# Leaving I am
# Help Thanks The For
# Help Thanks For The
# Thanks For Help The
# Thanks Help The For
# Have A Good Day
# Good Day A Have
# Have Good A Day
# Good A Have Day
# Care Take
# Take Care
# Thanks
# made you Who
# Who you made
# Who made you
# Your is Father Who
# Father Your Who is
# is Father Your Who

# %%
nltk.download("stopwords")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stemmer = LancasterStemmer()

# %%
def cleaning(sentences):
    words = []
    for s in sentences:
        clean = re.sub(r'[^ a-z A-Z 0-9]', " ", s)
        w = word_tokenize(clean)
        #stemming
        words.append([i.lower() for i in w])
    
    return words

# %%
cleaned_words = cleaning(sentences)

# %%
cleaned_words
# Out:
# [['hi'],
#  ['how', 'are', 'you'],
#  ['how', 'you', 'are'],
#  ['anyone', 'present', 'is'],
#  ['anyone', 'is', 'present'],
#  ['good', 'day'],
#  ['up', 'whats'],
#  ['how', 'do', 'you', 'do'],
#  ['do', 'do', 'you', 'how'],
#  ['do', 'do', 'you', 'how'],
#  ['how', 'do', 'do', 'you'],
#  ['hey'],
#  ['hello'],
#  ['greetings'],
#  ['goodbye'],
#  ['again', 'see', 'you'],
#  ['see', 'you', 'again'],
#  ['ciao'],
#  ['hasta', 'vista', 'la'],
#  ['hasta', 'la', 'vista'],
#  ['au', 'revior'],
#  ['am', 'i', 'leaving'],
#  ['leaving', 'i', 'am'],
#  ['help', 'thanks', 'the', 'for'],
#  ['help', 'thanks', 'for', 'the'],
#  ['thanks', 'for', 'help', 'the'],
#  ['thanks', 'help', 'the', 'for'],
#  ['have', 'a', 'good', 'day'],
#  ['good', 'day', 'a', 'have'],
#  ['have', 'good', 'a', 'day'],
#  ['good', 'a', 'have', 'day'],
#  ['care', 'take'],
#  ['take', 'care'],
#  ['thanks'],
#  ['made', 'you', 'who'],
#  ['who', 'you', 'made'],
#  ['who', 'made', 'you'],
#  ['your', 'is', 'father', 'who'],
#  ['father', 'your', 'who', 'is'],
#  ['is', 'father', 'your', 'who'],
#  ['who', 'father', 'is', 'your'],
#  ['who', 'is', 'creator', 'your'],
#  ['who', 'creator', 'is', 'your'],
#  ['creator', 'your', 'is', 'who'],
#  ['creator', 'your', 'who', 'is'],
#  ['creator'],
#  ['father'],
#  ['whats', 'your', 'age'],
#  ['your', 'age', 'whats'],
#  ['how', 'old', 'are', 'you'],
#  ['how', 'old'],
#  ['age'],
#  ['you', 'do', 'can', 'what'],
#  ['you', 'what', 'do', 'can'],
#  ['what', 'do', 'can', 'you'],
#  ['you', 'what', 'can', 'do'],
#  ['is', 'functionalities', 'what', 'your'],
#  ['your', 'functionalities', 'what', 'is'],
#  ['what', 'your', 'functionalities', 'is'],
#  ['is', 'your', 'what', 'functionalities'],
#  ['functions'],
#  ['abilities'],
#  ['uses'],
#  ['tell', 'me', 'you', 'what', 'do'],
#  ['me', 'you', 'what', 'do', 'tell'],
#  ['what', 'me', 'do', 'tell', 'you'],
#  ['me', 'you', 'do', 'tell', 'what'],
#  ['do', 'tell', 'me', 'what', 'you'],
#  ['what', 'to', 'do', 'if', 'cuts'],
#  ['how', 'to', 'cure', 'cuts'],
#  ['which', 'medicine', 'to', 'apply', 'for', 'cuts'],
#  ['what', 'to', 'apply', 'on', 'cuts'],
#  ['cuts'],
#  ['how', 'do', 'you', 'treat', 'abrasions'],
#  ['do', 'abrasions', 'cause', 'scars'],
#  ['abrasions'],
#  ['what', 'to', 'do', 'if', 'abrasions'],
#  ['which', 'medicine', 'to', 'apply', 'for', 'abrasions'],
#  ['how', 'to', 'cure', 'abrasions'],
#  ['how', 'do', 'you', 'treat', 'sting'],
#  ['stings'],
#  ['what', 'to', 'do', 'if', 'you', 'get', 'a', 'sting'],
#  ['which', 'medicine', 'to', 'apply', 'if', 'sting'],
#  ['how', 'to', 'remove', 'splinters'],
#  ['how', 'to', 'cure', 'splinters'],
#  ['what', 'to', 'do', 'if', 'i', 'have', 'splinters'],
#  ['how', 'do', 'you', 'bring', 'a', 'splinter', 'to', 'the', 'surface'],
#  ['how', 'do', 'you', 'treat', 'a', 'sprain'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'sprain'],
#  ['which', 'cream', 'to', 'apply', 'if', 'i', 'get', 'a', 'sprain'],
#  ['which', 'medicine', 'to', 'apply', 'if', 'i', 'get', 'a', 'sprain'],
#  ['how', 'do', 'you', 'treat', 'a', 'strain'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'strain'],
#  ['which', 'cream', 'to', 'apply', 'if', 'i', 'get', 'a', 'strain'],
#  ['which', 'medicine', 'to', 'apply', 'if', 'i', 'get', 'a', 'strain'],
#  ['how', 'do', 'you', 'diagnose', 'a', 'strain'],
#  ['is', 'heat', 'or', 'ice', 'better', 'for', 'a', 'pulled', 'muscle'],
#  ['how', 'do', 'you', 'treat', 'a', 'mild', 'fever'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'mild', 'fever'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'a', 'mild', 'fever'],
#  ['fever'],
#  ['how', 'do', 'you', 'treat', 'nasal', 'congestion'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'nasal', 'congestion'],
#  ['which',
#   'medicine',
#   'to',
#   'take',
#   'if',
#   'i',
#   'have',
#   'a',
#   'nasal',
#   'congestion'],
#  ['what', 'to', 'do', 'if', 'i', 'have', 'a', 'blocked', 'nose'],
#  ['how', 'do', 'you', 'treat', 'a', 'blocked', 'nose'],
#  ['how', 'long', 'does', 'nasal', 'congestion', 'last'],
#  ['how', 'to', 'cure', 'cough'],
#  ['how', 'do', 'you', 'treat', 'cough'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'cough'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'cough'],
#  ['how', 'do', 'you', 'get', 'rid', 'of', 'cough'],
#  ['how', 'do', 'you', 'treat', 'sore', 'throat'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'sore', 'throat'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'a', 'sore', 'throat'],
#  ['how', 'to', 'cure', 'sore', 'throat'],
#  ['how', 'do', 'you', 'treat', 'gas', 'problems'],
#  ['what', 'to', 'do', 'if', 'i', 'have', 'gastrointestinal', 'problems'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'gas', 'problem'],
#  ['how', 'to', 'cure', 'gas', 'problems'],
#  ['how', 'do', 'you', 'treat', 'skin', 'problems'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'skin', 'allergy'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'a', 'skin', 'allergy'],
#  ['how', 'to', 'cure', 'skin', 'allergy'],
#  ['how', 'do', 'you', 'treat', 'abdonominal', 'pain'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'abdonominal', 'pain'],
#  ['which',
#   'medicine',
#   'to',
#   'take',
#   'if',
#   'i',
#   'get',
#   'a',
#   'abdonominal',
#   'pain'],
#  ['how', 'to', 'cure', 'abdonominal', 'pain'],
#  ['how', 'do', 'you', 'treat', 'bruises'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'bruise'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'a', 'bruise'],
#  ['how', 'to', 'cure', 'bruises'],
#  ['how', 'do', 'you', 'treat', 'a', 'broken', 'toe'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'broken', 'toe'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'a', 'broken', 'toe'],
#  ['how', 'to', 'cure', 'broken', 'toe'],
#  ['how', 'do', 'you', 'treat', 'choking'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'choke'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'choked'],
#  ['how', 'to', 'cure', 'choking'],
#  ['how', 'do', 'you', 'treat', 'a', 'wound'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'wound'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'wounded'],
#  ['how', 'to', 'cure', 'a', 'wound'],
#  ['how', 'do', 'you', 'treat', 'diarrhea'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'diarrhea'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'diarrhea'],
#  ['how', 'to', 'cure', 'diarrhea'],
#  ['how', 'do', 'you', 'treat', 'a', 'frost', 'bite'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'frost', 'bite'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'a', 'frost', 'bite'],
#  ['how', 'to', 'cure', 'frost', 'bite'],
#  ['how', 'do', 'you', 'treat', 'heat', 'exhaustion'],
#  ['what', 'to', 'do', 'if', 'i', 'feel', 'exhausted', 'due', 'to', 'heat'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'exhausted'],
#  ['how', 'to', 'cure', 'heat', 'exhaustion'],
#  ['how', 'do', 'you', 'treat', 'heat', 'stroke'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'heat', 'stroke'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'stroke'],
#  ['how', 'to', 'cure', 'a', 'heat', 'stroke'],
#  ['how', 'do', 'you', 'treat', 'a', 'insect', 'bite'],
#  ['what', 'to', 'do', 'if', 'a', 'insect', 'bites', 'me'],
#  ['which',
#   'medicine',
#   'to',
#   'take',
#   'if',
#   'i',
#   'get',
#   'bitten',
#   'by',
#   'a',
#   'insect'],
#  ['how', 'to', 'cure', 'insect', 'bite'],
#  ['how', 'do', 'you', 'treat', 'a', 'bleeding', 'nose'],
#  ['what', 'to', 'do', 'if', 'i', 'my', 'nose', 'is', 'bleeding'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'nose', 'bleed'],
#  ['how', 'to', 'cure', 'nose', 'bleeding'],
#  ['how', 'do', 'you', 'treat', 'a', 'pulled', 'muscle'],
#  ['what', 'to', 'do', 'if', 'my', 'muscle', 'is', 'pulled'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'got', 'pulled', 'muscle'],
#  ['how', 'to', 'cure', 'a', 'pulled', 'muscle'],
#  ['how', 'do', 'you', 'treat', 'rectal', 'bleeding'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'rectal', 'bleeding'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'rectal', 'bleeding'],
#  ['how', 'to', 'cure', 'rectal', 'bleeding'],
#  ['how', 'do', 'you', 'treat', 'sun', 'burn'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'sun', 'burn'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'sun', 'burn'],
#  ['how', 'to', 'cure', 'a', 'sun', 'burn'],
#  ['how', 'do', 'you', 'treat', 'testicle', 'pain'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'testicle', 'pain'],
#  ['which',
#   'medicine',
#   'to',
#   'take',
#   'if',
#   'i',
#   'get',
#   'a',
#   'testicle',
#   'pain'],
#  ['how', 'to', 'cure', 'testicle', 'pain'],
#  ['how', 'do', 'you', 'treat', 'a', 'vertigo'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'vertigo'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'vertigo'],
#  ['how', 'to', 'cure', 'a', 'vertigo'],
#  ['how', 'do', 'you', 'treat', 'bleeding'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'bleeding'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'bleeding'],
#  ['how', 'to', 'cure', 'bleeding'],
#  ['how', 'do', 'you', 'treat', 'an', 'eye', 'injury'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'eye', 'injury'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'injured', 'my', 'eye'],
#  ['how', 'to', 'cure', 'injured', 'eye'],
#  ['how', 'do', 'you', 'treat', 'a', 'chemical', 'burn'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'chemical', 'burn'],
#  ['which',
#   'medicine',
#   'to',
#   'take',
#   'if',
#   'i',
#   'get',
#   'burn',
#   'due',
#   'to',
#   'chemicals'],
#  ['how', 'to', 'cure', 'chemical', 'burn'],
#  ['how', 'do', 'you', 'treat', 'a', 'poison'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'poison'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'am', 'poisoned'],
#  ['how', 'to', 'cure', 'poisoning'],
#  ['how', 'do', 'you', 'treat', 'broken', 'teeth'],
#  ['what', 'to', 'do', 'if', 'my', 'teeth', 'got', 'broken'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'broken', 'teeth'],
#  ['cure', 'broken', 'teeth'],
#  ['how', 'do', 'you', 'treat', 'a', 'seizure'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'seizure'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'seizure'],
#  ['how', 'to', 'cure', 'seizure'],
#  ['how', 'do', 'you', 'treat', 'a', 'head', 'injury'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'head', 'injury'],
#  ['which',
#   'medicine',
#   'to',
#   'take',
#   'if',
#   'i',
#   'get',
#   'injured',
#   'in',
#   'the',
#   'head'],
#  ['how', 'to', 'cure', 'head', 'injury'],
#  ['how', 'do', 'you', 'treat', 'faint'],
#  ['what', 'to', 'do', 'if', 'i', 'feel', 'like', 'fainting'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'a', 'faint'],
#  ['how', 'to', 'cure', 'fainting'],
#  ['how', 'do', 'you', 'treat', 'a', 'mild', 'headache'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'mild', 'headache'],
#  ['which',
#   'medicine',
#   'to',
#   'take',
#   'if',
#   'i',
#   'have',
#   'a',
#   'mild',
#   'headache'],
#  ['how', 'to', 'cure', 'a', 'mild', 'headache'],
#  ['how', 'do', 'you', 'treat', 'a', 'cold'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'mild', 'cold'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'have', 'a', 'cold'],
#  ['how', 'to', 'cure', 'cold'],
#  ['how', 'do', 'you', 'treat', 'rashes'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'rash'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'have', 'a', 'rash'],
#  ['how', 'to', 'cure', 'rash'],
#  ['how', 'do', 'you', 'treat', 'a', 'snake', 'bite'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'snake', 'bite'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'a', 'snake', 'bite'],
#  ['how', 'to', 'cure', 'snake', 'bite'],
#  ['i', 'got', 'bit', 'by', 'a', 'snake'],
#  ['how', 'do', 'you', 'treat', 'a', 'animal', 'bite'],
#  ['how', 'do', 'you', 'treat', 'a', 'monkey', 'bite'],
#  ['how', 'do', 'you', 'treat', 'a', 'dog', 'bite'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'animal', 'bite'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'get', 'a', 'monekey', 'bite'],
#  ['how', 'to', 'cure', 'dog', 'bite'],
#  ['i', 'got', 'bit', 'by', 'a', 'dog'],
#  ['what', 'to', 'do', 'if', 'someone', 'is', 'drowning'],
#  ['what', 'to', 'do', 'if', 'someone', 'drowned'],
#  ['what', 'steps', 'to', 'take', 'if', 'i', 'see', 'a', 'drowning', 'person'],
#  ['how', 'to', 'help', 'a', 'drowning', 'person'],
#  ['how', 'to', 'give', 'cpr'],
#  ['what', 'to', 'do', 'in', 'a', 'cpr'],
#  ['what', 'steps', 'to', 'take', 'in', 'a', 'cpr'],
#  ['how', 'to', 'help', 'a', 'drowning', 'person', 'in', 'cpr'],
#  ['how', 'do', 'you', 'treat', 'a', 'fracture'],
#  ['what', 'to', 'do', 'if', 'i', 'get', 'a', 'fracture'],
#  ['which', 'medicine', 'to', 'take', 'if', 'i', 'have', 'a', 'fracture'],
#  ['how', 'to', 'cure', 'a', 'fracture'],
#  ['sore',
#   'watery',
#   'throat',
#   'itchy',
#   'sneezing',
#   'nasal',
#   'congestion',
#   'nose',
#   'runny',
#   'eyes'],
#  ['eyes',
#   'congestion',
#   'itchy',
#   'watery',
#   'sneezing',
#   'runny',
#   'throat',
#   'nose',
#   'nasal',
#   'sore'],
#  ['itchy',
#   'congestion',
#   'sore',
#   'eyes',
#   'runny',
#   'watery',
#   'sneezing',
#   'throat',
#   'nose',
#   'nasal'],
#  ['watery',
#   'sneezing',
#   'throat',
#   'itchy',
#   'clearing',
#   'from',
#   'eyes',
#   'nose',
#   'nasal',
#   'drip',
#   'throat',
#   'cough',
#   'congestion',
#   'postnasal',
#   'scratchy'],
#  ['watery',
#   'nasal',
#   'itchy',
#   'throat',
#   'from',
#   'throat',
#   'scratchy',
#   'drip',
#   'nose',
#   'cough',
#   'sneezing',
#   'clearing',
#   'congestion',
#   'eyes',
#   'postnasal'],
#  ['scratchy',
#   'cough',
#   'eyes',
#   'drip',
#   'sneezing',
#   'itchy',
#   'congestion',
#   'throat',
#   'nose',
#   'throat',
#   'clearing',
#   'postnasal',
#   'watery',
#   'from',
#   'nasal'],
#  ['nasal',
#   'eyes',
#   'itchy',
#   'throat',
#   'postnasal',
#   'nose',
#   'watery',
#   'throat',
#   'scratchy',
#   'cough',
#   'from',
#   'clearing',
#   'drip',
#   'sneezing',
#   'congestion'],
#  ['drip',
#   'sneezing',
#   'throat',
#   'nose',
#   'from',
#   'congestion',
#   'clearing',
#   'itchy',
#   'nasal',
#   'throat',
#   'eyes',
#   'cough',
#   'postnasal',
#   'scratchy',
#   'watery'],
#  ['throat',
#   'eyes',
#   'drip',
#   'nose',
#   'postnasal',
#   'cough',
#   'congestion',
#   'itchy',
#   'throat',
#   'from',
#   'clearing',
#   'scratchy',
#   'sneezing',
#   'watery',
#   'nasal'],
#  ['of',
#   'palpitations',
#   'feel',
#   'fainting',
#   'have',
#   'decreased',
#   'pale',
#   'appear',
#   'shortness',
#   'rate',
#   'rapid',
#   'energy',
#   'heart',
#   'breath',
#   'easily',
#   'experience',
#   'develop',
#   'weakness',
#   'fatigue',
#   'tired'],
#  ['fainting',
#   'decreased',
#   'shortness',
#   'feel',
#   'energy',
#   'experience',
#   'tired',
#   'have',
#   'weakness',
#   'palpitations',
#   'fatigue',
#   'breath',
#   'of',
#   'develop',
#   'appear',
#   'easily',
#   'pale',
#   'rapid',
#   'rate',
#   'heart'],
#  ['palpitations',
#   'rapid',
#   'fainting',
#   'weakness',
#   'appear',
#   'energy',
#   'rate',
#   'experience',
#   'have',
#   'tired',
#   'decreased',
#   'shortness',
#   'develop',
#   'breath',
#   'pale',
#   'fatigue',
#   'heart',
#   'of',
#   'feel',
#   'easily'],
#  ['decreased',
#   'shortness',
#   'pale',
#   'tired',
#   'weakness',
#   'rapid',
#   'heart',
#   'of',
#   'have',
#   'breath',
#   'rate',
#   'appear',
#   'palpitations',
#   'energy',
#   'fainting',
#   'easily',
#   'experience',
#   'feel',
#   'fatigue',
#   'develop'],
#  ['shortness',
#   'heart',
#   'feel',
#   'weakness',
#   'pale',
#   'tired',
#   'develop',
#   'fatigue',
#   'appear',
#   'of',
#   'breath',
#   'experience',
#   'decreased',
#   'energy',
#   'have',
#   'palpitations',
#   'rate',
#   'rapid',
#   'fainting',
#   'easily'],
#  ['fainting',
#   'heart',
#   'appear',
#   'fatigue',
#   'feel',
#   'easily',
#   'of',
#   'pale',
#   'rate',
#   'weakness',
#   'develop',
#   'breath',
#   'tired',
#   'energy',
#   'have',
#   'palpitations',
#   'rapid',
#   'experience',
#   'decreased',
#   'shortness'],
#  ['easily',
#   'palpitations',
#   'rapid',
#   'have',
#   'fainting',
#   'fatigue',
#   'develop',
#   'energy',
#   'weakness',
#   'tired',
#   'experience',
#   'rate',
#   'feel',
#   'pale',
#   'decreased',
#   'appear',
#   'shortness',
#   'breath',
#   'heart',
#   'of'],
#  ['feel',
#   'fatigue',
#   'breath',
#   'experience',
#   'fainting',
#   'tired',
#   'easily',
#   'palpitations',
#   'weakness',
#   'decreased',
#   'develop',
#   'rapid',
#   'shortness',
#   'energy',
#   'pale',
#   'of',
#   'appear',
#   'rate',
#   'have',
#   'heart'],
#  ['congestion',
#   'headaches',
#   'cough',
#   'body',
#   'nosesneezing',
#   'throat',
#   'symptoms',
#   'nasal',
#   'sore',
#   'runny',
#   'fever',
#   'aches'],
#  ['aches',
#   'sore',
#   'body',
#   'fever',
#   'runny',
#   'congestion',
#   'throat',
#   'nosesneezing',
#   'symptoms',
#   'cough',
#   'headaches',
#   'nasal'],
#  ['cough',
#   'body',
#   'throat',
#   'aches',
#   'sore',
#   'nosesneezing',
#   'headaches',
#   'fever',
#   'congestion',
#   'runny',
#   'symptoms',
#   'nasal'],
#  ['runny',
#   'aches',
#   'symptoms',
#   'body',
#   'nosesneezing',
#   'congestion',
#   'headaches',
#   'cough',
#   'sore',
#   'nasal',
#   'throat',
#   'fever'],
#  ['cough', 'breath', 'pain', 'chest', 'of', 'shortness'],
#  ['chest', 'pain', 'breath', 'of', 'shortness', 'cough'],
#  ['cough', 'breath', 'shortness', 'pain', 'of', 'chest'],
#  ['agitation', 'quarrelsomeness', 'loss', 'irritability', 'of', 'orientation'],
#  ['of', 'orientation', 'loss', 'agitation', 'irritability', 'quarrelsomeness'],
#  ['orientation', 'loss', 'quarrelsomeness', 'irritability', 'of', 'agitation'],
#  ['of',
#   'tenderness',
#   'periods',
#   'food',
#   'cravings',
#   'breast',
#   'swelling',
#   'absence',
#   'menstrual'],
#  ['of',
#   'swelling',
#   'menstrual',
#   'food',
#   'periods',
#   'tenderness',
#   'absence',
#   'cravings',
#   'breast'],
#  ['periods',
#   'menstrual',
#   'cravings',
#   'absence',
#   'tenderness',
#   'of',
#   'food',
#   'breast',
#   'swelling'],
#  ['food',
#   'breast',
#   'absence',
#   'tenderness',
#   'menstrual',
#   'swelling',
#   'of',
#   'cravings',
#   'periods'],
#  ['sweating',
#   'loss',
#   'weight',
#   'nervousness',
#   'heart',
#   'intolerance',
#   'agitation',
#   'to',
#   'a',
#   'heat',
#   'tremor',
#   'rate',
#   'rapid',
#   'excessive',
#   'loss',
#   'hair',
#   'fatigue'],
#  ['excessive',
#   'intolerance',
#   'fatigue',
#   'a',
#   'loss',
#   'rapid',
#   'tremor',
#   'heat',
#   'nervousness',
#   'loss',
#   'weight',
#   'sweating',
#   'rate',
#   'to',
#   'agitation',
#   'heart',
#   'hair'],
#  ['loss',
#   'heat',
#   'weight',
#   'agitation',
#   'a',
#   'rate',
#   'fatigue',
#   'tremor',
#   'to',
#   'intolerance',
#   'rapid',
#   'sweating',
#   'excessive',
#   'nervousness',
#   'hair',
#   'loss',
#   'heart'],
#  ['heart',
#   'excessive',
#   'sweating',
#   'fatigue',
#   'weight',
#   'intolerance',
#   'a',
#   'tremor',
#   'heat',
#   'agitation',
#   'loss',
#   'nervousness',
#   'hair',
#   'loss',
#   'rate',
#   'to',
#   'rapid'],
#  ['loss',
#   'heat',
#   'hair',
#   'sweating',
#   'heart',
#   'excessive',
#   'a',
#   'tremor',
#   'rate',
#   'loss',
#   'agitation',
#   'rapid',
#   'nervousness',
#   'intolerance',
#   'to',
#   'weight',
#   'fatigue'],
#  ['fatigue',
#   'cramps',
#   'dry',
#   'intolerance',
#   'muscle',
#   'gain',
#   'weight',
#   'depression',
#   'skin',
#   'sleepiness',
#   'cold',
#   'mild'],
#  ['gain',
#   'weight',
#   'mild',
#   'cold',
#   'muscle',
#   'intolerance',
#   'depression',
#   'cramps',
#   'dry',
#   'fatigue',
#   'skin',
#   'sleepiness'],
#  ['dry',
#   'gain',
#   'intolerance',
#   'cold',
#   'skin',
#   'depression',
#   'weight',
#   'sleepiness',
#   'fatigue',
#   'cramps',
#   'muscle',
#   'mild'],
#  ['thirst', 'dehydration', 'hunger', 'increased', 'urination', 'increased'],
#  ['hunger', 'urination', 'increased', 'thirst', 'dehydration', 'increased'],
#  ['urination', 'dehydration', 'hunger', 'increased', 'thirst', 'increased'],
#  ['chills',
#   'ulcers',
#   'sweats',
#   'swollen',
#   'muscle',
#   'aches',
#   'lymph',
#   'mouth',
#   'throat',
#   'sore',
#   'nodes',
#   'night',
#   'fever',
#   'joint'],
#  ['mouth',
#   'joint',
#   'night',
#   'throat',
#   'sweats',
#   'sore',
#   'chills',
#   'fever',
#   'muscle',
#   'lymph',
#   'nodes',
#   'ulcers',
#   'swollen',
#   'aches'],
#  ['throat',
#   'lymph',
#   'joint',
#   'swollen',
#   'sore',
#   'night',
#   'chills',
#   'sweats',
#   'aches',
#   'nodes',
#   'ulcers',
#   'muscle',
#   'fever',
#   'mouth'],
#  ['swollen',
#   'fever',
#   'sweats',
#   'throat',
#   'lymph',
#   'chills',
#   'aches',
#   'ulcers',
#   'muscle',
#   'joint',
#   'sore',
#   'mouth',
#   'night',
#   'nodes'],
#  ['in',
#   'shortness',
#   'pain',
#   'of',
#   'blurred',
#   'vision',
#   'headache',
#   'chest',
#   'nosebleeds',
#   'the',
#   'breath',
#   'blood',
#   'fatigue',
#   'urine',
#   'dizziness'],
#  ['fatigue',
#   'dizziness',
#   'pain',
#   'headache',
#   'nosebleeds',
#   'blood',
#   'chest',
#   'breath',
#   'of',
#   'the',
#   'urine',
#   'vision',
#   'blurred',
#   'shortness',
#   'in'],
#  ['fatigue',
#   'dizziness',
#   'chest',
#   'blurred',
#   'the',
#   'pain',
#   'nosebleeds',
#   'shortness',
#   'of',
#   'urine',
#   'in',
#   'vision',
#   'breath',
#   'headache',
#   'blood'],
#  ['nosebleeds',
#   'blood',
#   'pain',
#   'shortness',
#   'chest',
#   'in',
#   'breath',
#   'vision',
#   'of',
#   'the',
#   'dizziness',
#   'headache',
#   'fatigue',
#   'blurred',
#   'urine'],
#  ['pain',
#   'shortness',
#   'nosebleeds',
#   'breath',
#   'in',
#   'vision',
#   'fatigue',
#   'of',
#   'dizziness',
#   'blurred',
#   'blood',
#   'headache',
#   'the',
#   'urine',
#   'chest'],
#  ['of',
#   'stiffness',
#   'muscle',
#   'fatigue',
#   'of',
#   'energy',
#   'aches',
#   'appetite',
#   'ache',
#   'fever',
#   'lack',
#   'loss'],
#  ['aches',
#   'of',
#   'lack',
#   'of',
#   'loss',
#   'ache',
#   'energy',
#   'fatigue',
#   'fever',
#   'muscle',
#   'stiffness',
#   'appetite'],
#  ['of',
#   'lack',
#   'of',
#   'loss',
#   'fatigue',
#   'stiffness',
#   'appetite',
#   'fever',
#   'muscle',
#   'energy',
#   'aches',
#   'ache'],
#  ['muscle',
#   'appetite',
#   'fever',
#   'fatigue',
#   'aches',
#   'lack',
#   'stiffness',
#   'energy',
#   'ache',
#   'of',
#   'of',
#   'loss'],
#  ['fatigue',
#   'the',
#   'abdomen',
#   'jaundice',
#   'upper',
#   'inflamed',
#   'of',
#   'in',
#   'right',
#   'pain',
#   'appetite',
#   'nausea',
#   'loss',
#   'liver'],
#  ['the',
#   'inflamed',
#   'loss',
#   'upper',
#   'of',
#   'abdomen',
#   'liver',
#   'in',
#   'pain',
#   'jaundice',
#   'appetite',
#   'nausea',
#   'right',
#   'fatigue'],
#  ['loss',
#   'appetite',
#   'nausea',
#   'inflamed',
#   'right',
#   'of',
#   'in',
#   'fatigue',
#   'the',
#   'liver',
#   'abdomen',
#   'upper',
#   'pain',
#   'jaundice'],
#  ['right',
#   'upper',
#   'loss',
#   'inflamed',
#   'in',
#   'abdomen',
#   'nausea',
#   'liver',
#   'the',
#   'fatigue',
#   'of',
#   'appetite',
#   'pain',
#   'jaundice'],
#  ['loss',
#   'liver',
#   'appetite',
#   'the',
#   'of',
#   'upper',
#   'pain',
#   'jaundice',
#   'inflamed',
#   'right',
#   'nausea',
#   'abdomen',
#   'fatigue',
#   'in'],
#  ['fever',
#   'fever',
#   'pain',
#   'exhaustion',
#   'headache',
#   'muscle',
#   'rash',
#   'joint',
#   'severe',
#   'headache'],
#  ['headache',
#   'joint',
#   'muscle',
#   'pain',
#   'headache',
#   'rash',
#   'exhaustion',
#   'fever',
#   'severe',
#   'fever'],
#  ['fever',
#   'headache',
#   'joint',
#   'fever',
#   'rash',
#   'headache',
#   'pain',
#   'severe',
#   'exhaustion',
#   'muscle'],
#  ['muscle',
#   'pain',
#   'headache',
#   'severe',
#   'fever',
#   'headache',
#   'exhaustion',
#   'fever',
#   'rash',
#   'joint'],
#  ['general',
#   'weakness',
#   'vomiting',
#   'chills',
#   'aches',
#   'nausea',
#   'headaches',
#   'fever',
#   'body'],
#  ['nausea',
#   'vomiting',
#   'headaches',
#   'aches',
#   'weakness',
#   'general',
#   'fever',
#   'chills',
#   'body'],
#  ['weakness',
#   'body',
#   'nausea',
#   'aches',
#   'chills',
#   'headaches',
#   'general',
#   'fever',
#   'vomiting'],
#  ['body',
#   'headaches',
#   'chills',
#   'general',
#   'aches',
#   'nausea',
#   'vomiting',
#   'fever',
#   'weakness'],
#  ['general',
#   'red',
#   'on',
#   'fever',
#   'the',
#   'body',
#   'weakness',
#   'spots',
#   'fever'],
#  ['fever',
#   'body',
#   'on',
#   'general',
#   'spots',
#   'red',
#   'weakness',
#   'the',
#   'fever'],
#  ['fever',
#   'the',
#   'red',
#   'on',
#   'general',
#   'weakness',
#   'fever',
#   'body',
#   'spots'],
#  ['on',
#   'fever',
#   'general',
#   'the',
#   'fever',
#   'spots',
#   'weakness',
#   'body',
#   'red'],
#  ['skin',
#   'discoloration',
#   'the',
#   'mucous',
#   'yellow',
#   'muscle',
#   'seizures',
#   'membranes',
#   'crying',
#   'high',
#   'of',
#   'pitched',
#   'changes',
#   'in',
#   'sleepiness',
#   'tone'],
#  ['seizures',
#   'the',
#   'high',
#   'pitched',
#   'membranes',
#   'discoloration',
#   'changes',
#   'sleepiness',
#   'yellow',
#   'tone',
#   'of',
#   'crying',
#   'skin',
#   'in',
#   'mucous',
#   'muscle'],
#  ['high',
#   'skin',
#   'membranes',
#   'seizures',
#   'yellow',
#   'crying',
#   'changes',
#   'in',
#   'of',
#   'muscle',
#   'tone',
#   'pitched',
#   'mucous',
#   'sleepiness',
#   'the',
#   'discoloration'],
#  ['muscle',
#   'of',
#   'tone',
#   'seizures',
#   'changes',
#   'in',
#   'skin',
#   'sleepiness',
#   'membranes',
#   'crying',
#   'the',
#   'yellow',
#   'high',
#   'mucous',
#   'discoloration',
#   'pitched'],
#  ['frequent',
#   'pain',
#   'watery',
#   'bowel',
#   'movements',
#   'abdominal',
#   'no',
#   'inflammation',
#   'signs',
#   'cramping',
#   'of',
#   'are'],
#  ['pain',
#   'signs',
#   'watery',
#   'of',
#   'abdominal',
#   'no',
#   'movements',
#   'frequent',
#   'inflammation',
#   'are',
#   'cramping',
#   'bowel'],
#  ['bowel',
#   'cramping',
#   'frequent',
#   'inflammation',
#   'movements',
#   'watery',
#   'of',
#   'pain',
#   'no',
#   'abdominal',
#   'are',
#   'signs'],
#  ['are',
#   'watery',
#   'cramping',
#   'of',
#   'frequent',
#   'signs',
#   'no',
#   'pain',
#   'movements',
#   'bowel',
#   'inflammation',
#   'abdominal'],
#  ['decrease',
#   'fully',
#   'glasses',
#   'in',
#   'with',
#   'correctable',
#   'clarity',
#   'of',
#   'vision',
#   'not'],
#  ['not',
#   'correctable',
#   'of',
#   'with',
#   'in',
#   'vision',
#   'decrease',
#   'clarity',
#   'fully',
#   'glasses'],
#  ['glasses',
#   'decrease',
#   'of',
#   'not',
#   'with',
#   'vision',
#   'in',
#   'clarity',
#   'fully',
#   'correctable'],
#  ['vision',
#   'correctable',
#   'in',
#   'clarity',
#   'of',
#   'fully',
#   'decrease',
#   'glasses',
#   'not',
#   'with'],
#  ['fully',
#   'of',
#   'correctable',
#   'not',
#   'in',
#   'decrease',
#   'clarity',
#   'glasses',
#   'with',
#   'vision'],
#  ['fatigue', 'fever', 'of', 'cough', 'chills', 'breath', 'shortness'],
#  ['of', 'cough', 'fever', 'fatigue', 'shortness', 'chills', 'breath'],
#  ['fever', 'chills', 'fatigue', 'of', 'cough', 'shortness', 'breath'],
#  ['of', 'chills', 'fever', 'fatigue', 'cough', 'shortness', 'breath'],
#  ['lower',
#   'to',
#   'the',
#   'in',
#   'of',
#   'inability',
#   'urinate',
#   'bloating',
#   'abdomen',
#   'lower',
#   'the',
#   'abdomen',
#   'discomfort',
#   'painful'],
#  ['abdomen',
#   'the',
#   'abdomen',
#   'inability',
#   'the',
#   'to',
#   'bloating',
#   'painful',
#   'lower',
#   'discomfort',
#   'lower',
#   'urinate',
#   'of',
#   'in'],
#  ['urinate',
#   'the',
#   'painful',
#   'abdomen',
#   'lower',
#   'discomfort',
#   'inability',
#   'to',
#   'in',
#   'abdomen',
#   'of',
#   'lower',
#   'bloating',
#   'the'],
#  ['painful',
#   'urinate',
#   'to',
#   'inability',
#   'lower',
#   'of',
#   'the',
#   'abdomen',
#   'the',
#   'bloating',
#   'lower',
#   'discomfort',
#   'in',
#   'abdomen'],
#  ['abdomen',
#   'bloating',
#   'urinate',
#   'lower',
#   'in',
#   'lower',
#   'inability',
#   'the',
#   'of',
#   'the',
#   'discomfort',
#   'abdomen',
#   'painful',
#   'to'],
#  ['mood',
#   'of',
#   'fatigue',
#   'concentration',
#   'daytime',
#   'changes',
#   'anxiety',
#   'po',
#   'of',
#   'sleep',
#   'sleepiness',
#   'lack',
#   'lack',
#   'energy',
#   'headaches',
#   'attention'],
#  ['mood',
#   'fatigue',
#   'lack',
#   'po',
#   'of',
#   'of',
#   'changes',
#   'anxiety',
#   'lack',
#   'energy',
#   'headaches',
#   'daytime',
#   'sleep',
#   'attention',
#   'concentration',
#   'sleepiness'],
#  ['daytime',
#   'sleepiness',
#   'lack',
#   'fatigue',
#   'changes',
#   'sleep',
#   'anxiety',
#   'lack',
#   'energy',
#   'concentration',
#   'headaches',
#   'attention',
#   'of',
#   'po',
#   'of',
#   'mood'],
#  ['of',
#   'energy',
#   'mood',
#   'daytime',
#   'lack',
#   'sleepiness',
#   'po',
#   'headaches',
#   'sleep',
#   'of',
#   'fatigue',
#   'lack',
#   'anxiety',
#   'changes',
#   'concentration',
#   'attention'],
#  ['changes',
#   'lack',
#   'of',
#   'of',
#   'daytime',
#   'anxiety',
#   'attention',
#   'concentration',
#   'mood',
#   'fatigue',
#   'headaches',
#   'energy',
#   'po',
#   'sleepiness',
#   'sleep',
#   'lack'],
#  ['cough',
#   'fever',
#   'tenderness',
#   'sore',
#   'sinuses',
#   'pressure',
#   'in',
#   'pain',
#   'the',
#   'ears',
#   'in',
#   'cloudy',
#   'the',
#   'headache',
#   'throat',
#   'nasal',
#   'teeth',
#   'sinus',
#   'discolored',
#   'facial'],
#  ['ears',
#   'cloudy',
#   'discolored',
#   'headache',
#   'teeth',
#   'nasal',
#   'pain',
#   'cough',
#   'facial',
#   'in',
#   'pressure',
#   'sinuses',
#   'the',
#   'fever',
#   'sore',
#   'in',
#   'sinus',
#   'tenderness',
#   'throat',
#   'the'],
#  ['nasal',
#   'in',
#   'tenderness',
#   'sinus',
#   'cough',
#   'cloudy',
#   'discolored',
#   'sinuses',
#   'sore',
#   'ears',
#   'pressure',
#   'the',
#   'pain',
#   'throat',
#   'in',
#   'facial',
#   'the',
#   'teeth',
#   'fever',
#   'headache'],
#  ['sinus',
#   'the',
#   'headache',
#   'the',
#   'facial',
#   'sinuses',
#   'fever',
#   'pain',
#   'in',
#   'pressure',
#   'nasal',
#   'tenderness',
#   'ears',
#   'teeth',
#   'sore',
#   'cough',
#   'in',
#   'throat',
#   'cloudy',
#   'discolored'],
#  ['sore',
#   'the',
#   'sinus',
#   'cough',
#   'tenderness',
#   'throat',
#   'the',
#   'pain',
#   'facial',
#   'discolored',
#   'fever',
#   'nasal',
#   'in',
#   'in',
#   'cloudy',
#   'ears',
#   'teeth',
#   'sinuses',
#   'pressure',
#   'headache'],
#  ['pressure',
#   'in',
#   'teeth',
#   'facial',
#   'sinuses',
#   'the',
#   'cloudy',
#   'the',
#   'discolored',
#   'sinus',
#   'cough',
#   'sore',
#   'tenderness',
#   'throat',
#   'fever',
#   'nasal',
#   'headache',
#   'pain',
#   'ears',
#   'in'],
#  ['aches', 'of', 'loss', 'fever', 'muscle', 'fatigue', 'appetite'],
#  ['fever', 'loss', 'appetite', 'muscle', 'of', 'aches', 'fatigue'],
#  ['of', 'loss', 'aches', 'fatigue', 'fever', 'appetite', 'muscle'],
#  ['aches', 'fever', 'of', 'loss', 'appetite', 'muscle', 'fatigue'],
#  ['painful',
#   'loss',
#   'swollen',
#   'glands',
#   'appetite',
#   'salivary',
#   'fever',
#   'fatigue',
#   'headache'],
#  ['appetite',
#   'painful',
#   'headache',
#   'salivary',
#   'fever',
#   'loss',
#   'glands',
#   'fatigue',
#   'swollen'],
#  ['loss',
#   'headache',
#   'glands',
#   'fatigue',
#   'salivary',
#   'fever',
#   'swollen',
#   'painful',
#   'appetite'],
#  ['loss',
#   'glands',
#   'painful',
#   'salivary',
#   'swollen',
#   'headache',
#   'fatigue',
#   'appetite',
#   'fever'],
#  ['cough', 'conjunctivitis', 'runny', 'fever', 'high', 'nose', 'dry'],
#  ['runny', 'conjunctivitis', 'high', 'dry', 'cough', 'nose', 'fever'],
#  ['cough', 'fever', 'high', 'nose', 'dry', 'runny', 'conjunctivitis'],
#  ['muscle',
#   'dry',
#   'difficulty',
#   'swallowing',
#   'vision',
#   'weakness',
#   'drooping',
#   'double',
#   'mouth',
#   'blurred',
#   'vision',
#   'eyelids'],
#  ['double',
#   'drooping',
#   'weakness',
#   'muscle',
#   'dry',
#   'swallowing',
#   'mouth',
#   'blurred',
#   'eyelids',
#   'vision',
#   'difficulty',
#   'vision'],
#  ['vision',
#   'mouth',
#   'weakness',
#   'drooping',
#   'eyelids',
#   'vision',
#   'difficulty',
#   'swallowing',
#   'blurred',
#   'double',
#   'dry',
#   'muscle'],
#  ['vision',
#   'drooping',
#   'difficulty',
#   'muscle',
#   'double',
#   'swallowing',
#   'mouth',
#   'blurred',
#   'dry',
#   'eyelids',
#   'vision',
#   'weakness'],
#  ['rapid', 'deterioration', 'mental'],
#  ['mental', 'rapid', 'deterioration'],
#  ['neck',
#   'irritability',
#   'sudden',
#   'stiff',
#   'loss',
#   'headache',
#   'memory',
#   'back',
#   'loss',
#   'weakness',
#   'muscle',
#   'vomiting',
#   'seizures',
#   'of',
#   'po',
#   'confusion',
#   'consciousness',
#   'fever',
#   'responsiveness',
#   'drowsiness'],
#  ['confusion',
#   'of',
#   'memory',
#   'responsiveness',
#   'fever',
#   'loss',
#   'consciousness',
#   'sudden',
#   'loss',
#   'muscle',
#   'back',
#   'headache',
#   'po',
#   'irritability',
#   'drowsiness',
#   'seizures',
#   'stiff',
#   'weakness',
#   'neck',
#   'vomiting'],
#  ['loss',
#   'loss',
#   'weakness',
#   'seizures',
#   'confusion',
#   'po',
#   'sudden',
#   'stiff',
#   'irritability',
#   'vomiting',
#   'memory',
#   'fever',
#   'of',
#   'responsiveness',
#   'neck',
#   'consciousness',
#   'headache',
#   'muscle',
#   'back',
#   'drowsiness'],
#  ['vomiting',
#   'muscle',
#   'back',
#   'memory',
#   'fever',
#   'loss',
#   'confusion',
#   'of',
#   'drowsiness',
#   'po',
#   'loss',
#   'sudden',
#   'seizures',
#   'headache',
#   'responsiveness',
#   'weakness',
#   'irritability',
#   'consciousness',
#   'neck',
#   'stiff'],
#  ['of',
#   'loss',
#   'irritability',
#   'muscle',
#   'vomiting',
#   'loss',
#   'memory',
#   'seizures',
#   'stiff',
#   'responsiveness',
#   'consciousness',
#   'headache',
#   'fever',
#   'confusion',
#   'back',
#   'weakness',
#   'neck',
#   'po',
#   'drowsiness',
#   'sudden'],
#  ['fever',
#   'drowsiness',
#   'sudden',
#   'vomiting',
#   'headache',
#   'confusion',
#   'weakness',
#   'consciousness',
#   'seizures',
#   'back',
#   'irritability',
#   'of',
#   'po',
#   'loss',
#   'muscle',
#   'stiff',
#   'loss',
#   'memory',
#   'responsiveness',
#   'neck'],
#  ['upper',
#   'nausea',
#   'vomiting',
#   'pain',
#   'abdominal',
#   'abdominal',
#   'distention'],
#  ['vomiting',
#   'pain',
#   'upper',
#   'abdominal',
#   'distention',
#   'nausea',
#   'abdominal'],
#  ['pain',
#   'nausea',
#   'upper',
#   'vomiting',
#   'distention',
#   'abdominal',
#   'abdominal'],
#  ['distention',
#   'upper',
#   'abdominal',
#   'abdominal',
#   'nausea',
#   'vomiting',
#   'pain'],
#  ['less',
#   'bleeding',
#   'diarrhea',
#   'fissures',
#   'prolapse',
#   'lower',
#   'rectal',
#   'movements',
#   'anal',
#   'abdominal',
#   'bowel',
#   'discomfort'],
#  ['diarrhea',
#   'anal',
#   'bowel',
#   'rectal',
#   'less',
#   'prolapse',
#   'movements',
#   'fissures',
#   'lower',
#   'discomfort',
#   'abdominal',
#   'bleeding'],
#  ['prolapse',
#   'discomfort',
#   'anal',
#   'abdominal',
#   'less',
#   'rectal',
#   'fissures',
#   'lower',
#   'bowel',
#   'bleeding',
#   'diarrhea',
#   'movements'],
#  ['prolapse',
#   'fissures',
#   'abdominal',
#   'movements',
#   'less',
#   'bowel',
#   'bleeding',
#   'discomfort',
#   'lower',
#   'diarrhea',
#   'anal',
#   'rectal'],
#  ['lower',
#   'rectal',
#   'fissures',
#   'anal',
#   'bleeding',
#   'abdominal',
#   'bowel',
#   'diarrhea',
#   'movements',
#   'prolapse',
#   'less',
#   'discomfort'],
#  ['fissures',
#   'bowel',
#   'diarrhea',
#   'rectal',
#   'anal',
#   'abdominal',
#   'movements',
#   'bleeding',
#   'prolapse',
#   'discomfort',
#   'lower',
#   'less'],
#  ['appetite',
#   'tenderness',
#   'nausea',
#   'of',
#   'pain',
#   'abdominal',
#   'fever',
#   'vomiting',
#   'loss',
#   'abdominal'],
#  ['fever',
#   'of',
#   'pain',
#   'vomiting',
#   'tenderness',
#   'abdominal',
#   'nausea',
#   'loss',
#   'appetite',
#   'abdominal'],
#  ['tenderness',
#   'pain',
#   'of',
#   'nausea',
#   'vomiting',
#   'fever',
#   'abdominal',
#   'abdominal',
#   'appetite',
#   'loss'],
#  ['nausea',
#   'abdominal',
#   'loss',
#   'fever',
#   'pain',
#   'appetite',
#   'tenderness',
#   'of',
#   'abdominal',
#   'vomiting'],
#  ['may',
#   'fatigue',
#   'trouble',
#   'problems',
#   'sleep',
#   'irritabilityheadaches',
#   'attention',
#   'concentrating',
#   'restlessness',
#   'problems',
#   'as',
#   'that',
#   'appear',
#   'also',
#   'memory'],
#  ['problems',
#   'that',
#   'concentrating',
#   'fatigue',
#   'sleep',
#   'may',
#   'memory',
#   'appear',
#   'restlessness',
#   'also',
#   'as',
#   'trouble',
#   'problems',
#   'attention',
#   'irritabilityheadaches'],
#  ['also',
#   'fatigue',
#   'concentrating',
#   'as',
#   'trouble',
#   'restlessness',
#   'may',
#   'attention',
#   'sleep',
#   'memory',
#   'problems',
#   'that',
#   'appear',
#   'problems',
#   'irritabilityheadaches'],
#  ['also',
#   'as',
#   'sleep',
#   'problems',
#   'memory',
#   'that',
#   'fatigue',
#   'appear',
#   'trouble',
#   'concentrating',
#   'may',
#   'problems',
#   'irritabilityheadaches',
#   'attention',
#   'restlessness'],
#  ['problems',
#   'memory',
#   'irritabilityheadaches',
#   'sleep',
#   'also',
#   'may',
#   'problems',
#   'concentrating',
#   'that',
#   'restlessness',
#   'appear',
#   'as',
#   'fatigue',
#   'trouble',
#   'attention'],
#  ['weight',
#   'loss',
#   'diarrhea',
#   'pain',
#   'diarrhea',
#   'vomiting',
#   'bloody',
#   'fever',
#   'abdominal'],
#  ['bloody',
#   'vomiting',
#   'loss',
#   'abdominal',
#   'fever',
#   'weight',
#   'diarrhea',
#   'pain',
#   'diarrhea'],
#  ['pain',
#   'bloody',
#   'loss',
#   'diarrhea',
#   'diarrhea',
#   'abdominal',
#   'vomiting',
#   'weight',
#   'fever'],
#  ['diarrhea',
#   'loss',
#   'abdominal',
#   'diarrhea',
#   'bloody',
#   'fever',
#   'weight',
#   'pain',
#   'vomiting'],
#  ['sleep',
#   'droopy',
#   'double',
#   'paralysis',
#   'daytime',
#   'hallucinations',
#   'vision',
#   'eyelids',
#   'excessive',
#   'sleepiness'],
#  ['double',
#   'droopy',
#   'paralysis',
#   'excessive',
#   'sleep',
#   'sleepiness',
#   'daytime',
#   'vision',
#   'hallucinations',
#   'eyelids'],
#  ['eyelids',
#   'sleep',
#   'droopy',
#   'double',
#   'sleepiness',
#   'excessive',
#   'hallucinations',
#   'paralysis',
#   'vision',
#   'daytime'],
#  ['eyelids',
#   'sleepiness',
#   'hallucinations',
#   'paralysis',
#   'sleep',
#   'vision',
#   'excessive',
#   'double',
#   'daytime',
#   'droopy'],
#  ['paralysis',
#   'hallucinations',
#   'excessive',
#   'double',
#   'vision',
#   'droopy',
#   'daytime',
#   'eyelids',
#   'sleepiness',
#   'sleep'],
#  ['urine',
#   'blood',
#   'kidney',
#   'in',
#   'in',
#   'tract',
#   'urinary',
#   'infections',
#   'pain',
#   'tractu',
#   'painstones',
#   'the',
#   'rinary',
#   'the'],
#  ['blood',
#   'urine',
#   'rinary',
#   'urinary',
#   'painstones',
#   'the',
#   'the',
#   'kidney',
#   'infections',
#   'tract',
#   'tractu',
#   'pain',
#   'in',
#   'in'],
#  ['the',
#   'rinary',
#   'kidney',
#   'infections',
#   'blood',
#   'in',
#   'urinary',
#   'urine',
#   'tract',
#   'painstones',
#   'the',
#   'in',
#   'pain',
#   'tractu'],
#  ['blood',
#   'tract',
#   'in',
#   'urine',
#   'kidney',
#   'infections',
#   'in',
#   'pain',
#   'the',
#   'the',
#   'urinary',
#   'tractu',
#   'painstones',
#   'rinary'],
#  ['in',
#   'infections',
#   'urine',
#   'in',
#   'tract',
#   'pain',
#   'tractu',
#   'painstones',
#   'blood',
#   'kidney',
#   'the',
#   'the',
#   'rinary',
#   'urinary'],
#  ['infections',
#   'in',
#   'tract',
#   'urinary',
#   'blood',
#   'kidney',
#   'in',
#   'the',
#   'tractu',
#   'rinary',
#   'painstones',
#   'urine',
#   'the',
#   'pain'],
#  ['urinating',
#   'back',
#   'pain',
#   'pain',
#   'pain',
#   'blood',
#   'groin',
#   'low',
#   'pain',
#   'rectal',
#   'fever',
#   'abdominal'],
#  ['pain',
#   'fever',
#   'low',
#   'pain',
#   'rectal',
#   'abdominal',
#   'blood',
#   'groin',
#   'pain',
#   'back',
#   'urinating',
#   'pain'],
#  ['fever',
#   'rectal',
#   'pain',
#   'pain',
#   'low',
#   'pain',
#   'back',
#   'urinating',
#   'groin',
#   'pain',
#   'blood',
#   'abdominal'],
#  ['groin',
#   'back',
#   'blood',
#   'pain',
#   'pain',
#   'fever',
#   'pain',
#   'pain',
#   'urinating',
#   'rectal',
#   'low',
#   'abdominal'],
#  ['to',
#   'fullness',
#   'pressure',
#   'heaviness',
#   'that',
#   'the',
#   'goes',
#   'of',
#   'shortness',
#   'breath',
#   'chest',
#   'pain',
#   'arm',
#   'tightness',
#   'sweating',
#   'ache'],
#  ['ache',
#   'goes',
#   'heaviness',
#   'chest',
#   'shortness',
#   'pressure',
#   'pain',
#   'tightness',
#   'sweating',
#   'of',
#   'the',
#   'that',
#   'breath',
#   'fullness',
#   'arm',
#   'to'],
#  ['pain',
#   'the',
#   'tightness',
#   'of',
#   'breath',
#   'chest',
#   'that',
#   'goes',
#   'sweating',
#   'pressure',
#   'ache',
#   'shortness',
#   'arm',
#   'fullness',
#   'to',
#   'heaviness'],
#  ['tightness',
#   'goes',
#   'heaviness',
#   'that',
#   'ache',
#   'fullness',
#   'of',
#   'arm',
#   'pain',
#   'chest',
#   'sweating',
#   'to',
#   'breath',
#   'the',
#   'pressure',
#   'shortness'],
#  ['tightness',
#   'shortness',
#   'breath',
#   'that',
#   'goes',
#   'to',
#   'of',
#   'pressure',
#   'sweating',
#   'the',
#   'pain',
#   'arm',
#   'fullness',
#   'chest',
#   'ache',
#   'heaviness'],
#  ['coma',
#   'aches',
#   'skin',
#   'headache',
#   'paralysis',
#   'fever',
#   'sleepiness',
#   'stiff',
#   'disorientation',
#   'convulsions',
#   'neck',
#   'body',
#   'tremors',
#   'rash'],
#  ['coma',
#   'convulsions',
#   'body',
#   'rash',
#   'skin',
#   'paralysis',
#   'stiff',
#   'disorientation',
#   'sleepiness',
#   'fever',
#   'tremors',
#   'neck',
#   'aches',
#   'headache'],
#  ['headache',
#   'disorientation',
#   'tremors',
#   'paralysis',
#   'coma',
#   'skin',
#   'sleepiness',
#   'stiff',
#   'neck',
#   'rash',
#   'fever',
#   'body',
#   'convulsions',
#   'aches'],
#  ['aches',
#   'sleepiness',
#   'stiff',
#   'tremors',
#   'skin',
#   'fever',
#   'disorientation',
#   'body',
#   'paralysis',
#   'neck',
#   'convulsions',
#   'rash',
#   'headache',
#   'coma'],
#  ['stiff',
#   'paralysis',
#   'sleepiness',
#   'fever',
#   'rash',
#   'disorientation',
#   'skin',
#   'coma',
#   'aches',
#   'convulsions',
#   'headache',
#   'tremors',
#   'neck',
#   'body'],
#  ['pressure',
#   'blood',
#   'fevers',
#   'chills',
#   'pus',
#   'swollen',
#   'red',
#   'low',
#   'high'],
#  ['low',
#   'red',
#   'swollen',
#   'fevers',
#   'pus',
#   'high',
#   'pressure',
#   'chills',
#   'blood'],
#  ['low',
#   'swollen',
#   'chills',
#   'red',
#   'pus',
#   'high',
#   'pressure',
#   'blood',
#   'fevers'],
#  ['red',
#   'fevers',
#   'blood',
#   'pus',
#   'low',
#   'chills',
#   'high',
#   'swollen',
#   'pressure'],
#  ['vision', 'blurred'],
#  ['flashing', 'lights', 'floaters'],
#  ['lights', 'floaters', 'flashing'],
#  ['vision', 'of', 'haziness', 'blurriness'],
#  ['blurriness', 'haziness', 'vision', 'of'],
#  ['cancer',
#   'the',
#   'periods',
#   'pelvic',
#   'heavy',
#   'womb',
#   'uterus',
#   'ovaries',
#   'the',
#   'of',
#   'pain',
#   'cervix',
#   'of',
#   'prolapse'],
#  ['the',
#   'ovaries',
#   'uterus',
#   'cancer',
#   'the',
#   'pelvic',
#   'heavy',
#   'of',
#   'cervix',
#   'prolapse',
#   'periods',
#   'pain',
#   'of',
#   'womb'],
#  ['of',
#   'ovaries',
#   'of',
#   'heavy',
#   'uterus',
#   'prolapse',
#   'cervix',
#   'cancer',
#   'pelvic',
#   'the',
#   'pain',
#   'the',
#   'periods',
#   'womb'],
#  ['that', 'is', 'typically', 'odorless', 'vaginal', 'a', 'discharge', 'thick'],
#  ['thick', 'vaginal', 'a', 'that', 'discharge', 'is', 'typically', 'odorless'],
#  ['upset',
#   'easily',
#   'irritable',
#   'withdrawal',
#   'sleep',
#   'worsen',
#   'depression',
#   'underweight',
#   'social',
#   'disrupted'],
#  ['social',
#   'depression',
#   'irritable',
#   'easily',
#   'upset',
#   'worsen',
#   'disrupted',
#   'sleep',
#   'withdrawal',
#   'underweight'],
#  ['worsen',
#   'withdrawal',
#   'upset',
#   'depression',
#   'underweight',
#   'sleep',
#   'irritable',
#   'social',
#   'easily',
#   'disrupted'],
#  ['discomfort', 'of', 'chest', 'wheezing', 'breath', 'shortness', 'cough'],
#  ['wheezing', 'cough', 'chest', 'breath', 'discomfort', 'of', 'shortness'],
#  ['wheezing', 'shortness', 'cough', 'chest', 'breath', 'discomfort', 'of'],
#  ['shortness', 'wheezing', 'breath', 'of'],
#  ['breath', 'shortness', 'of', 'wheezing'],
#  ['of', 'shortness', 'breath', 'wheezing'],
#  ['area',
#   'from',
#   'infection',
#   'areas',
#   'grows',
#   'of',
#   'which',
#   'hair',
#   'skin',
#   'tiny',
#   'of'],
#  ['skin',
#   'grows',
#   'hair',
#   'infection',
#   'of',
#   'areas',
#   'which',
#   'tiny',
#   'area',
#   'of',
#   'from'],
#  ['infection',
#   'grows',
#   'tiny',
#   'area',
#   'hair',
#   'skin',
#   'areas',
#   'which',
#   'of',
#   'from',
#   'of'],
#  ['hair',
#   'of',
#   'of',
#   'areas',
#   'grows',
#   'area',
#   'skin',
#   'tiny',
#   'from',
#   'which',
#   'infection'],
#  ['shaped',
#   'in',
#   'col',
#   'look',
#   'red',
#   'from',
#   'pink',
#   'shiny',
#   'ranging',
#   'raised',
#   'to',
#   'dome'],
#  ['in',
#   'to',
#   'ranging',
#   'col',
#   'raised',
#   'look',
#   'pink',
#   'red',
#   'shaped',
#   'dome',
#   'from',
#   'shiny'],
#  ['red',
#   'look',
#   'in',
#   'ranging',
#   'shaped',
#   'col',
#   'dome',
#   'to',
#   'shiny',
#   'pink',
#   'from',
#   'raised'],
#  ['ranging',
#   'dome',
#   'shaped',
#   'from',
#   'red',
#   'in',
#   'shiny',
#   'pink',
#   'look',
#   'col',
#   'raised',
#   'to'],
#  ['pink',
#   'look',
#   'to',
#   'ranging',
#   'raised',
#   'from',
#   'col',
#   'red',
#   'dome',
#   'shaped',
#   'shiny',
#   'in'],
#  ['small',
#   'flushing',
#   'cysts',
#   'facial',
#   'the',
#   'of',
#   'blushing',
#   'tissue',
#   'redness',
#   'acial',
#   'skin',
#   'thickening'],
#  ['acial',
#   'small',
#   'facial',
#   'redness',
#   'flushing',
#   'thickening',
#   'blushing',
#   'of',
#   'tissue',
#   'the',
#   'cysts',
#   'skin'],
#  ['small',
#   'thickening',
#   'flushing',
#   'skin',
#   'of',
#   'redness',
#   'facial',
#   'blushing',
#   'tissue',
#   'the',
#   'acial',
#   'cysts'],
#  ['thickening',
#   'redness',
#   'acial',
#   'small',
#   'tissue',
#   'skin',
#   'cysts',
#   'the',
#   'of',
#   'flushing',
#   'facial',
#   'blushing'],
#  ['skin',
#   'blushing',
#   'the',
#   'small',
#   'acial',
#   'thickening',
#   'redness',
#   'cysts',
#   'tissue',
#   'flushing',
#   'facial',
#   'of'],
#  ['blistering',
#   'fever',
#   'aches',
#   'fluid',
#   'body',
#   'pain',
#   'rash',
#   'nausea',
#   'stinging',
#   'stabbing',
#   'burning',
#   'chills',
#   'itching',
#   'tingling',
#   'rash',
#   'one',
#   'filled',
#   'sided',
#   'headache',
#   'red',
#   'sensation'],
#  ['rash',
#   'chills',
#   'headache',
#   'stinging',
#   'fever',
#   'blistering',
#   'filled',
#   'pain',
#   'red',
#   'aches',
#   'body',
#   'itching',
#   'stabbing',
#   'sided',
#   'sensation',
#   'burning',
#   'one',
#   'tingling',
#   'nausea',
#   'rash',
#   'fluid'],
#  ['headache',
#   'burning',
#   'stabbing',
#   'body',
#   'aches',
#   'pain',
#   'fever',
#   'rash',
#   'sided',
#   'chills',
#   'tingling',
#   'filled',
#   'stinging',
#   'itching',
#   'red',
#   'nausea',
#   'blistering',
#   'one',
#   'fluid',
#   'rash',
#   'sensation'],
#  ['tingling',
#   'one',
#   'chills',
#   'blistering',
#   'nausea',
#   'sided',
#   'headache',
#   'filled',
#   'sensation',
#   'fluid',
#   'rash',
#   'burning',
#   'body',
#   'stabbing',
#   'itching',
#   'fever',
#   'rash',
#   'stinging',
#   'pain',
#   'red',
#   'aches'],
#  ['fluid',
#   'chills',
#   'stinging',
#   'body',
#   'itching',
#   'tingling',
#   'filled',
#   'burning',
#   'sided',
#   'rash',
#   'aches',
#   'nausea',
#   'rash',
#   'one',
#   'blistering',
#   'pain',
#   'fever',
#   'headache',
#   'red',
#   'sensation',
#   'stabbing'],
#  ['body',
#   'stinging',
#   'rash',
#   'tingling',
#   'pain',
#   'stabbing',
#   'fluid',
#   'one',
#   'rash',
#   'itching',
#   'chills',
#   'nausea',
#   'blistering',
#   'red',
#   'aches',
#   'sided',
#   'fever',
#   'burning',
#   'filled',
#   'headache',
#   'sensation'],
#  ['scaly', 'head', 'forehead', 'plaques', 'reddish'],
#  ['plaques', 'forehead', 'scaly', 'head', 'reddish'],
#  ['scaly', 'plaques', 'forehead', 'head', 'reddish'],
#  ['uninflamed', 'pus', 'filled', 'pimples', 'blackheads', 't'],
#  ['t', 'pimples', 'filled', 'blackheads', 'uninflamed', 'pus'],
#  ['blackheads', 'pimples', 'pus', 't', 'uninflamed', 'filled'],
#  ['growth', 'skin', 'painless', 'fleshy', 'the', 'on'],
#  ['skin', 'fleshy', 'growth', 'painless', 'on', 'the'],
#  ['fleshy', 'skin', 'painless', 'on', 'the', 'growth'],
#  ['tightness',
#   'swelling',
#   'pain',
#   'tenderness',
#   'redness',
#   'hardening',
#   'skin',
#   'itching'],
#  ['redness',
#   'skin',
#   'tightness',
#   'swelling',
#   'hardening',
#   'tenderness',
#   'pain',
#   'itching'],
#  ['redness',
#   'tightness',
#   'tenderness',
#   'itching',
#   'pain',
#   'swelling',
#   'hardening',
#   'skin'],
#  ['big',
#   'sever',
#   'violet',
#   'a',
#   'mild',
#   'colour',
#   'angular',
#   'bumps',
#   'borders',
#   'itching'],
#  ['bumps',
#   'big',
#   'itching',
#   'sever',
#   'colour',
#   'borders',
#   'angular',
#   'mild',
#   'violet',
#   'a'],
#  ['big',
#   'angular',
#   'bumps',
#   'a',
#   'sever',
#   'itching',
#   'borders',
#   'mild',
#   'colour',
#   'violet'],
#  ['itching',
#   'colour',
#   'big',
#   'bumps',
#   'borders',
#   'mild',
#   'a',
#   'violet',
#   'angular',
#   'sever'],
#  ['forgetfulness', 'simple', 'old', 'age'],
#  ['old', 'age', 'simple', 'forgetfulness'],
#  ['simple', 'forgetfulness', 'age', 'old'],
#  ['flare', 'itch', 'swell', 'welts'],
#  ['pain',
#   'abdominal',
#   'teeth',
#   'vomiting',
#   'skin',
#   'discolored',
#   'glands',
#   'throat',
#   'deteriorating',
#   'constipation',
#   'salivary',
#   'dehydration',
#   'swollen',
#   'dry',
#   'sore'],
#  ['dry',
#   'glands',
#   'teeth',
#   'skin',
#   'abdominal',
#   'constipation',
#   'sore',
#   'dehydration',
#   'deteriorating',
#   'vomiting',
#   'salivary',
#   'pain',
#   'throat',
#   'discolored',
#   'swollen'],
#  ['teeth',
#   'skin',
#   'dehydration',
#   'deteriorating',
#   'swollen',
#   'constipation',
#   'abdominal',
#   'vomiting',
#   'glands',
#   'salivary',
#   'pain',
#   'sore',
#   'throat',
#   'dry',
#   'discolored'],
#  ['dry',
#   'throat',
#   'dehydration',
#   'salivary',
#   'swollen',
#   'deteriorating',
#   'abdominal',
#   'pain',
#   'sore',
#   'skin',
#   'teeth',
#   'vomiting',
#   'glands',
#   'constipation',
#   'discolored'],
#  ['skin',
#   'vomiting',
#   'throat',
#   'salivary',
#   'glands',
#   'pain',
#   'swollen',
#   'constipation',
#   'discolored',
#   'dehydration',
#   'dry',
#   'teeth',
#   'abdominal',
#   'deteriorating',
#   'sore'],
#  ['sex',
#   'penile',
#   'of',
#   'penis',
#   'completion',
#   'occurs',
#   'f',
#   'hard',
#   'erection',
#   'enough'],
#  ['penis',
#   'sex',
#   'erection',
#   'enough',
#   'hard',
#   'penile',
#   'f',
#   'completion',
#   'occurs',
#   'of'],
#  ['penis',
#   'penile',
#   'of',
#   'enough',
#   'erection',
#   'f',
#   'hard',
#   'sex',
#   'completion',
#   'occurs'],
#  ['urgently',
#   'flow',
#   'tract',
#   'of',
#   'of',
#   'need',
#   'blockage',
#   'urinate',
#   'the',
#   'urine',
#   'urinary',
#   'to',
#   'infections',
#   'slow',
#   'urethra'],
#  ['of',
#   'the',
#   'urinary',
#   'flow',
#   'to',
#   'slow',
#   'urgently',
#   'need',
#   'urinate',
#   'of',
#   'blockage',
#   'urethra',
#   'tract',
#   'infections',
#   'urine'],
#  ['urine',
#   'of',
#   'of',
#   'urethra',
#   'need',
#   'infections',
#   'to',
#   'slow',
#   'urgently',
#   'urinate',
#   'urinary',
#   'flow',
#   'the',
#   'blockage',
#   'tract'],
#  ['of',
#   'slow',
#   'flow',
#   'urgently',
#   'need',
#   'tract',
#   'to',
#   'infections',
#   'urinate',
#   'urinary',
#   'urine',
#   'blockage',
#   'of',
#   'the',
#   'urethra'],
#  ['tract',
#   'blockage',
#   'of',
#   'urinary',
#   'urine',
#   'slow',
#   'need',
#   'flow',
#   'urinate',
#   'infections',
#   'the',
#   'to',
#   'urgently',
#   'urethra',
#   'of'],
#  ['hopelessness',
# ...
#   'walk',
#   'outside'],
#  ['are',
#   'people',
#   'with',
#   'respiratory',
#   'disease',
#   'more',
#   'likely',
#   'to',
#   'die',
#   'of',
#   'covid',
#   '19',
#   'than',
#   'those',
#   'without'],
#  ['as',
#   'part',
#   'of',
#   'my',
#   'condition',
#   'i',
#   'regularly',
#   'have',
#   'a',
#   'dry',
#   'cough',
#   'and',
#   'fever',
#   'is',
#   'there',
#   'a',
#   'way',
#   'to',
#   'distinguish',
#   'these',
#   'symptoms',
#   'with',
#   'those',
#   'of',
#   'covid',
#   '19'],
#  ['should',
#   'i',
#   'wear',
#   'a',
#   'mask',
#   'to',
#   'protect',
#   'myself',
#   'from',
#   'the',
#   'virus'],
#  ['can', 'i', 'catch', 'covid', '19', 'from', 'my', 'pet'],
#  ['my',
#   'neighbours',
#   'often',
#   'smoke',
#   'in',
#   'their',
#   'garden',
#   'and',
#   'the',
#   'smoke',
#   'comes',
#   'into',
#   'my',
#   'house',
#   'if',
#   'the',
#   'windows',
#   'are',
#   'open',
#   'can',
#   'covid',
#   '19',
#   'be',
#   'transmitted',
#   'through',
#   'exhaled',
#   'smoke'],
#  ['the',
#   'news',
#   'says',
#   'that',
#   'the',
#   'worst',
#   'affected',
#   'by',
#   'covid',
#   '19',
#   'are',
#   'the',
#   'older',
#   'age',
#   'population',
#   'and',
#   'people',
#   'with',
#   'pre',
#   'existing',
#   'conditions',
#   'are',
#   'people',
#   'with',
#   'pre',
#   'existing',
#   'conditions',
#   'also',
#   'older',
#   'or',
#   'does',
#   'this',
#   'refer',
#   'to',
#   'people',
#   'of',
#   'any',
#   'age'],
#  ['i',
#   'had',
#   'the',
#   'flu',
#   'vaccine',
#   'this',
#   'year',
#   'am',
#   'i',
#   'protected',
#   'from',
#   'this',
#   'virus'],
#  ['what',
#   'is',
#   'being',
#   'done',
#   'to',
#   'protect',
#   'the',
#   'vulnerable',
#   'population',
#   'elderly',
#   'people',
#   'with',
#   'health',
#   'conditions'],
#  ['what',
#   'are',
#   'organisations',
#   'in',
#   'europe',
#   'doing',
#   'about',
#   'the',
#   'situation'],
#  ['can',
#   'the',
#   'virus',
#   'that',
#   'causes',
#   'covid',
#   '19',
#   'be',
#   'transmitted',
#   'through',
#   'the',
#   'air'],
#  ['can',
#   'i',
#   'catch',
#   'covid',
#   '19',
#   'from',
#   'the',
#   'feces',
#   'of',
#   'someone',
#   'with',
#   'the',
#   'disease'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease'],
#  ['protection',
#   'measures',
#   'for',
#   'persons',
#   'who',
#   'are',
#   'in',
#   'or',
#   'have',
#   'recently',
#   'visited',
#   'past',
#   '14',
#   'days',
#   'areas',
#   'where',
#   'covid',
#   '19',
#   'is',
#   'spreading'],
#  ['how', 'likely', 'am', 'i', 'to', 'catch', 'covid', '19'],
#  ['should', 'i', 'worry', 'about', 'covid', '19'],
#  ['are',
#   'antibiotics',
#   'effective',
#   'in',
#   'preventing',
#   'or',
#   'treating',
#   'the',
#   'covid',
#   '19'],
#  ['are',
#   'there',
#   'any',
#   'medicines',
#   'or',
#   'therapies',
#   'that',
#   'can',
#   'prevent',
#   'or',
#   'cure',
#   'covid',
#   '19'],
#  ['should', 'i', 'wear', 'mask', 'to', 'protect', 'myself'],
#  ['how',
#   'to',
#   'put',
#   'on',
#   'use',
#   'take',
#   'off',
#   'and',
#   'dispose',
#   'of',
#   'a',
#   'mask'],
#  ['how', 'long', 'is', 'the', 'incubation', 'period', 'for', 'covid', '19'],
#  ['can', 'i', 'catch', 'covid', '19', 'from', 'my', 'pet'],
#  ['is',
#   'it',
#   'safe',
#   'to',
#   'receive',
#   'a',
#   'package',
#   'from',
#   'any',
#   'area',
#   'where',
#   'covid',
#   '19',
#   'has',
#   'been',
#   'reported'],
#  ['is', 'there', 'anything', 'i', 'should', 'not', 'do'],
#  ['can', 'you', 'have', 'covid', '19', 'and', 'show', 'no', 'symptoms'],
#  ['can', 'one', 'get', 'corona', 'virus', 'for', 'a', 'second', 'time'],
#  ['how', 'long', 'can', 'the', 'virus', 'survive', 'on', 'surfaces'],
#  ['how',
#   'has',
#   'attention',
#   'to',
#   'other',
#   'major',
#   'illnesses',
#   'like',
#   'cancer',
#   'been',
#   'affected'],
#  ['is',
#   'it',
#   'possible',
#   'that',
#   'one',
#   'day',
#   'this',
#   'will',
#   'happen',
#   'again'],
#  ['how', 'to', 'stop', 'infection', 'spreading', 'of', 'covid', '19'],
#  ['what', 'to', 'do', 'if', 'you', 'need', 'medical', 'help'],
#  ['how', 'to', 'protect', 'yourself', 'from', 'coronavirus'],
#  ['who', 'are', 'the', 'people', 'most', 'at', 'risk'],
#  ['what',
#   'are',
#   'the',
#   'symptoms',
#   'of',
#   'someone',
#   'infected',
#   'with',
#   'a',
#   'corona',
#   'virus'],
#  ['how', 'long', 'you', 'should', 'self', 'isolate'],
#  ['how', 'long', 'to', 'self', 'isolate', 'if', 'you', 'have', 'symptoms'],
#  ['what',
#   'to',
#   'do',
#   'if',
#   'you',
#   'live',
#   'with',
#   'someone',
#   'who',
#   'has',
#   'symptoms'],
#  ['what',
#   'should',
#   'be',
#   'done',
#   'to',
#   'reduce',
#   'the',
#   'spread',
#   'of',
#   'infection',
#   'in',
#   'your',
#   'home'],
#  ['how', 'to', 'treat', 'corona', 'virus', 'symptoms', 'at', 'home'],
#  ['can', 'i', 'take', 'ibuprofen', 'if', 'i', 'have', 'corona', 'virus'],
#  ['when', 'am', 'i', 'allowed', 'to', 'leave', 'the', 'house'],
#  ['can',
#   'i',
#   'go',
#   'to',
#   'the',
#   'dentist',
#   'my',
#   'gp',
#   'or',
#   'another',
#   'medical',
#   'appointment'],
#  ['should', 'i', 'stay', 'at', 'home', 'or', 'go', 'to', 'work'],
#  ['i',
#   'm',
#   'not',
#   'a',
#   'critical',
#   'worker',
#   'and',
#   'i',
#   'can',
#   't',
#   'work',
#   'from',
#   'home',
#   'what',
#   'should',
#   'i',
#   'do'],
#  ['how',
#   'can',
#   'i',
#   'find',
#   'out',
#   'if',
#   'my',
#   'work',
#   'is',
#   'essential',
#   'or',
#   'not'],
#  ['can', 'i', 'see', 'my', 'friends'],
#  ['can', 'i', 'visit', 'elderly', 'relatives'],
#  ['can', 'i', 'go', 'out', 'to', 'help', 'a', 'vulnerable', 'person'],
#  ['can', 'i', 'go', 'to', 'park'],
#  ['can', 'i', 'move', 'house'],
#  ['can',
#   'i',
#   'drive',
#   'to',
#   'a',
#   'national',
#   'park',
#   'or',
#   'other',
#   'green',
#   'space',
#   'to',
#   'walk'],
#  ['what', 'will', 'happen', 'to', 'me', 'if', 'i', 'break', 'the', 'rules'],
#  ['what', 'to', 'do', 'if', 'you', 'have', 'symptoms'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'prevent',
#   'catching',
#   'or',
#   'spreading',
#   'the',
#   'germs'],
#  ['are', 'the', 'intercollegiate', 'halls', 'of', 'residence', 'open'],
#  ['is', 'teaching', 'continuing', 'for', 'students'],
#  ['what', 'is', 'corona', 'virus'],
#  ['what', 'is', 'social', 'distancing'],
#  ['what', 'effect', 'does', 'coronavirus', 'have', 'on', 'pregnant', 'women'],
#  ['what',
#   'effect',
#   'will',
#   'coronavirus',
#   'have',
#   'on',
#   'my',
#   'baby',
#   'if',
#   'i',
#   'am',
#   'diagnosed',
#   'with',
#   'the',
#   'infection'],
#  ['why', 'are', 'pregnant', 'women', 'in', 'a', 'vulnerable', 'group'],
#  ['what', 'is', 'the', 'travel', 'advice', 'if', 'i', 'am', 'pregnant'],
#  ['should',
#   'i',
#   'attend',
#   'my',
#   'antenatal',
#   'and',
#   'postnatal',
#   'appointments'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'i',
#   'develop',
#   'a',
#   'fever',
#   'or',
#   'temperature',
#   'or',
#   'both',
#   'when',
#   'i',
#   'am',
#   'pregnant'],
#  ['what',
#   'impact',
#   'will',
#   'corona',
#   'virus',
#   'have',
#   'on',
#   'my',
#   'pregnancy'],
#  ['will',
#   'my',
#   'childbirth',
#   'choices',
#   'be',
#   'affected',
#   'by',
#   'the',
#   'coronavirus',
#   'pandemic'],
#  ['will',
#   'i',
#   'be',
#   'able',
#   'to',
#   'have',
#   'my',
#   'birth',
#   'partner',
#   'with',
#   'me',
#   'during',
#   'labour',
#   'and',
#   'birth'],
#  ['will',
#   'i',
#   'be',
#   'able',
#   'to',
#   'have',
#   'my',
#   'birth',
#   'partner',
#   'with',
#   'me',
#   'if',
#   'i',
#   'am',
#   'being',
#   'induced'],
#  ['will',
#   'my',
#   'birth',
#   'partner',
#   'be',
#   'able',
#   'to',
#   'stay',
#   'with',
#   'me',
#   'if',
#   'i',
#   'have',
#   'a',
#   'caesarean',
#   'or',
#   'instrumental',
#   'birth',
#   'that',
#   'occurs',
#   'in',
#   'an',
#   'operating',
#   'theatre'],
#  ['is',
#   'there',
#   'any',
#   'advice',
#   'for',
#   'birth',
#   'partners',
#   'during',
#   'the',
#   'corona',
#   'virus',
#   'pandemic'],
#  ['how', 'will', 'i', 'be', 'tested', 'for', 'corona', 'virus'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'i',
#   'test',
#   'positive',
#   'for',
#   'coronavirus'],
#  ['why',
#   'would',
#   'i',
#   'be',
#   'asked',
#   'to',
#   'self',
#   'isolate',
#   'as',
#   'opposed',
#   'to',
#   'reducing',
#   'social',
#   'contact'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'i',
#   'm',
#   'asked',
#   'to',
#   'self',
#   'isolate'],
#  ['how',
#   'will',
#   'my',
#   'care',
#   'be',
#   'managed',
#   'after',
#   'i',
#   'have',
#   'recovered',
#   'from',
#   'coronavirus'],
#  ['what',
#   'do',
#   'i',
#   'do',
#   'if',
#   'i',
#   'feel',
#   'unwell',
#   'or',
#   'i',
#   'm',
#   'worried',
#   'about',
#   'my',
#   'baby',
#   'during',
#   'self',
#   'isolation'],
#  ['will',
#   'being',
#   'in',
#   'self',
#   'isolation',
#   'for',
#   'suspected',
#   'or',
#   'confirmed',
#   'corona',
#   'virus',
#   'affect',
#   'where',
#   'i',
#   'give',
#   'birth'],
#  ['will',
#   'being',
#   'in',
#   'self',
#   'isolation',
#   'for',
#   'suspected',
#   'or',
#   'confirmed',
#   'coronavirus',
#   'affect',
#   'how',
#   'i',
#   'give',
#   'birth'],
#  ['what',
#   'happens',
#   'if',
#   'i',
#   'go',
#   'into',
#   'labour',
#   'during',
#   'my',
#   'self',
#   'isolation',
#   'period'],
#  ['could', 'i', 'pass', 'corona', 'virus', 'to', 'my', 'baby'],
#  ['will', 'my', 'baby', 'be', 'tested', 'for', 'coronavirus'],
#  ['what', 'is', 'corona', 'virus'],
#  ['why',
#   'is',
#   'this',
#   'disease',
#   'being',
#   'called',
#   'corona',
#   'virus',
#   'disease',
#   '2019',
#   'covid',
#   '19'],
#  ['why',
#   'might',
#   'someone',
#   'blame',
#   'or',
#   'avoid',
#   'individuals',
#   'and',
#   'groups',
#   'create',
#   'stigma',
#   'because',
#   'of',
#   'covid',
#   '19'],
#  ['how',
#   'can',
#   'people',
#   'help',
#   'stop',
#   'stigma',
#   'related',
#   'to',
#   'covid',
#   '19'],
#  ['what', 'is', 'source', 'of', 'corona', 'virus'],
#  ['how', 'does', 'corona', 'virus', 'spread'],
#  ['why', 'are', 'we', 'seeing', 'rise', 'in', 'cases'],
#  ['can',
#   'someone',
#   'who',
#   'has',
#   'covid',
#   '19',
#   'spread',
#   'the',
#   'illness',
#   'to',
#   'others'],
#  ['can',
#   'the',
#   'corona',
#   'virus',
#   'can',
#   'be',
#   'spread',
#   'through',
#   'food',
#   'including',
#   'restaurant',
#   'take',
#   'out',
#   'refrigerated',
#   'or',
#   'frozen',
#   'packaged',
#   'food'],
#  ['can', 'i', 'get', 'sick', 'with', 'covid', '19', 'if', 'its', 'on', 'food'],
#  ['will', 'warm', 'weather', 'stop', 'the', 'outbreak', 'of', 'covid', '19'],
#  ['what', 'is', 'community', 'spread'],
#  ['what',
#   'temperature',
#   'kills',
#   'the',
#   'virus',
#   'that',
#   'causes',
#   'covid',
#   '19'],
#  ['can',
#   'mosquitoes',
#   'or',
#   'tricks',
#   'spread',
#   'the',
#   'virus',
#   'that',
#   'causes',
#   'covid',
#   '19'],
#  ['how', 'can', 'i', 'protect', 'myself'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'i',
#   'have',
#   'had',
#   'close',
#   'contact',
#   'with',
#   'someone',
#   'who',
#   'has',
#   'covid',
#   '19'],
#  ['does',
#   'cdc',
#   'recommend',
#   'using',
#   'face',
#   'masks',
#   'or',
#   'face',
#   'coverings',
#   'to',
#   'prevent',
#   'covid',
#   '19'],
#  ['am',
#   'i',
#   'at',
#   'risk',
#   'for',
#   'covid',
#   '19',
#   'from',
#   'a',
#   'package',
#   'or',
#   'products',
#   'shipping',
#   'from',
#   'china'],
#  ['is', 'it', 'okay', 'for', 'me', 'to', 'donate', 'blood'],
#  ['what',
#   'is',
#   'the',
#   'risk',
#   'of',
#   'my',
#   'child',
#   'becoming',
#   'sick',
#   'with',
#   'covid',
#   '19'],
#  ['how',
#   'can',
#   'i',
#   'protect',
#   'my',
#   'child',
#   'from',
#   'covid',
#   '19',
#   'infection'],
#  ['are',
#   'the',
#   'symptoms',
#   'of',
#   'covid',
#   '19',
#   'different',
#   'in',
#   'children',
#   'than',
#   'in',
#   'adults'],
#  ['should', 'children', 'wear', 'masks'],
#  ['how',
#   'do',
#   'i',
#   'prepare',
#   'my',
#   'children',
#   'in',
#   'case',
#   'of',
#   'covid',
#   '19',
#   'outbreak',
#   'in',
#   'our',
#   'community'],
#  ['how', 'can', 'my', 'family', 'and', 'i', 'prepare', 'for', 'covid', '19'],
#  ['what',
#   'steps',
#   'can',
#   'my',
#   'family',
#   'take',
#   'to',
#   'reduce',
#   'our',
#   'risk',
#   'of',
#   'getting',
#   'covid',
#   '19'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'someone',
#   'in',
#   'my',
#   'house',
#   'gets',
#   'sick',
#   'with',
#   'covid',
#   '19'],
#  ['how', 'can', 'i', 'prepare', 'for', 'covid', '19', 'at', 'work'],
#  ['should',
#   'i',
#   'use',
#   'soap',
#   'and',
#   'water',
#   'or',
#   'hand',
#   'sanitizer',
#   'to',
#   'protect',
#   'against',
#   'covid',
#   '19'],
#  ['what',
#   'cleaning',
#   'products',
#   'should',
#   'i',
#   'use',
#   'to',
#   'protect',
#   'against',
#   'covid',
#   '19'],
#  ['should',
#   'i',
#   'make',
#   'my',
#   'own',
#   'sanitizer',
#   'if',
#   'i',
#   'can',
#   't',
#   'find',
#   'it',
#   'in',
#   'the',
#   'stores'],
#  ['what',
#   'are',
#   'the',
#   'symptoms',
#   'and',
#   'complications',
#   'that',
#   'covid',
#   '19',
#   'can',
#   'cause'],
#  ['who',
#   'is',
#   'most',
#   'at',
#   'risk',
#   'for',
#   'the',
#   'corona',
#   'virus',
#   'disease'],
#  ['what',
#   'should',
#   'people',
#   'at',
#   'higher',
#   'risk',
#   'of',
#   'serious',
#   'illness',
#   'with',
#   'covid',
#   '19',
#   'do'],
#  ['can',
#   'i',
#   'get',
#   'covid',
#   '19',
#   'from',
#   'my',
#   'pets',
#   'or',
#   'other',
#   'animals'],
#  ['how', 'can', 'i', 'prevent', 'covid', '19'],
#  ['what', 'treatments', 'are', 'available', 'for', 'covid', '19'],
#  ['are',
#   'there',
#   'any',
#   'vaccines',
#   'or',
#   'other',
#   'medical',
#   'products',
#   'to',
#   'prevent',
#   'covid',
#   '19'],
#  ['can', 'covid', '19', 'be', 'transmitted', 'by', 'blood', 'transmission'],
#  ['is',
#   'it',
#   'safe',
#   'to',
#   'donate',
#   'blood',
#   'during',
#   'the',
#   'corona',
#   'virus',
#   'pandemic'],
#  ['are',
#   'there',
#   'any',
#   'fda',
#   'approved',
#   'drug',
#   'products',
#   'or',
#   'medicines',
#   'to',
#   'treat',
#   'covid',
#   '19'],
#  ['are',
#   'antibiotics',
#   'effective',
#   'in',
#   'preventing',
#   'or',
#   'treating',
#   'the',
#   'covid',
#   '19'],
#  ['is', 'there', 'a', 'test', 'for', 'covid', '19'],
#  ['how', 'are', 'people', 'tested', 'for', 'covid', '19'],
#  ['can',
#   'i',
#   'get',
#   'covid',
#   '19',
#   'from',
#   'food',
#   'worker',
#   'handling',
#   'my',
#   'food'],
#  ['can', 'animals', 'get', 'covid', '19', 'disease'],
#  ['can',
#   'i',
#   'get',
#   'covid',
#   '19',
#   'from',
#   'my',
#   'pets',
#   'or',
#   'other',
#   'animals'],
#  ['what',
#   'is',
#   'the',
#   'median',
#   'incubation',
#   'period',
#   'of',
#   'corona',
#   'virus'],
#  ['what', 'is', 'corona', 'virus'],
#  ['what', 'are', 'the', 'symptoms', 'of', 'covid', '19'],
#  ['how', 'does', 'covid', '19', 'spread'],
#  ['can',
#   'the',
#   'virus',
#   'that',
#   'causes',
#   'covid',
#   '19',
#   'be',
#   'transmitted',
#   'through',
#   'the',
#   'air'],
#  ['can',
#   'covid',
#   '19',
#   'be',
#   'caught',
#   'from',
#   'a',
#   'person',
#   'who',
#   'has',
#   'no',
#   'symptoms'],
#  ['can',
#   'i',
#   'catch',
#   'covid',
#   '19',
#   'from',
#   'the',
#   'feces',
#   'of',
#   'someone',
#   'with',
#   'the',
#   'disease'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'from',
#   'corona',
#   'virus'],
#  ['how', 'likely', 'am', 'i', 'to', 'catch', 'covid', '19'],
#  ['should', 'i', 'worry', 'about', 'covid', '19'],
#  ['who', 'is', 'at', 'risk', 'of', 'developing', 'severe', 'illness'],
#  ['are',
#   'antibiotics',
#   'effective',
#   'in',
#   'preventing',
#   'or',
#   'treating',
#   'the',
#   'covid',
#   '19'],
#  ['are',
#   'there',
#   'any',
#   'medicines',
#   'or',
#   'therapies',
#   'that',
#   'can',
#   'prevent',
#   'or',
#   'cure',
#   'covid',
#   '19'],
#  ['is',
#   'there',
#   'a',
#   'vaccine',
#   'drug',
#   'or',
#   'treatment',
#   'for',
#   'covid',
#   '19'],
#  ['is', 'covid', '19', 'the', 'same', 'as', 'sars'],
#  ['should', 'i', 'wear', 'mask', 'to', 'protect', 'myself'],
#  ['how',
#   'to',
#   'put',
#   'on',
#   'use',
#   'take',
#   'off',
#   'and',
#   'dispose',
#   'of',
#   'a',
#   'mask'],
#  ['can',
#   'humans',
#   'become',
#   'infected',
#   'with',
#   'the',
#   'covid',
#   '19',
#   'from',
#   'an',
#   'animal',
#   'source'],
#  ['can', 'i', 'catch', 'covid', '19', 'from', 'my', 'pet'],
#  ['how', 'long', 'does', 'the', 'virus', 'survive', 'on', 'surfaces'],
#  ['is',
#   'it',
#   'safe',
#   'to',
#   'receive',
#   'a',
#   'package',
#   'from',
#   'any',
#   'area',
#   'where',
#   'covid',
#   '19',
#   'has',
#   'been',
#   'reported'],
#  ['do',
#   'i',
#   'need',
#   'to',
#   'wear',
#   'a',
#   'mask',
#   'every',
#   'time',
#   'i',
#   'step',
#   'out',
#   'of',
#   'the',
#   'home'],
#  ['what',
#   'is',
#   'the',
#   'government',
#   'doing',
#   'to',
#   'contain',
#   'the',
#   'spread',
#   'of',
#   'covid',
#   '19'],
#  ['where',
#   'can',
#   'i',
#   'go',
#   'to',
#   'obtain',
#   'accurate',
#   'scientific',
#   'and',
#   'up',
#   'to',
#   'date',
#   'information',
#   'about',
#   'coronavirus'],
#  ['how',
#   'long',
#   'is',
#   'the',
#   'incubation',
#   'period',
#   'for',
#   'corona',
#   'virus'],
#  ['what',
#   'do',
#   'we',
#   'know',
#   'about',
#   'incubation',
#   'period',
#   'of',
#   'corona',
#   'virus']]

# %%
print(len(cleaned_words))
print(cleaned_words[:3])
# Out:
# 810
# [['hi'], ['how', 'are', 'you'], ['how', 'you', 'are']]

# %%
def create_tokenizer(words, filters = '!"#$%&()*+,-./:;<=>?@[\]^_`{|}~'):
    token = Tokenizer(filters = filters)
    token.fit_on_texts(words)
    return token

# %%
def max_length(words):
    return(len(max(words, key = len)))

# %%
word_tokenizer = create_tokenizer(cleaned_words)
vocab_size = len(word_tokenizer.word_index) + 1
max_length = max_length(cleaned_words)

print("Vocab Size = %d and Maximum length = %d" % (vocab_size, max_length))
# Out:
# Vocab Size = 927 and Maximum length = 40

# %%
def encoding_doc(token, words):
    return(token.texts_to_sequences(words))

# %%
encoded_doc = encoding_doc(word_tokenizer, cleaned_words)

# %%
def padding_doc(encoded_doc, max_length):
    return(pad_sequences(encoded_doc, maxlen = max_length, padding = "post"))

# %%
padded_doc = padding_doc(encoded_doc, max_length)

# %%
print("Shape of padded docs = ",padded_doc.shape)
# Out:
# Shape of padded docs =  (810, 40)

# %%
output_tokenizer = create_tokenizer(unique_intent, filters = '!"#$%&()*+,-/:;<=>?@[\]^`{|}~')

# %%
output_tokenizer.word_index
# Out:
# {'abdonominalpain': 66,
#  'abrasions': 209,
#  'again': 9,
#  'age': 126,
#  'allergycovid': 227,
#  'allergysymptoms': 78,
#  'animal': 69,
#  'animalbite': 155,
#  'animalsource': 60,
#  'animlas': 191,
#  'antibiotic': 89,
#  'appointment': 59,
#  'avoidinfecting': 109,
#  'baby': 214,
#  'birth': 98,
#  'brokentoe': 160,
#  'bruises': 11,
#  'bye': 85,
#  'catch': 32,
#  'chemicalburn': 239,
#  'child': 162,
#  'childcovid': 68,
#  'childmask': 193,
#  'choking': 183,
#  'cold': 71,
#  'community': 74,
#  'condition': 75,
#  'contact': 199,
#  'corona': 31,
#  'coronavirus': 196,
#  'cough': 88,
#  'covid': 64,
#  'covidinfluenza': 139,
#  'covidsars': 174,
#  'cpr': 164,
#  'creator': 240,
#  'cuts': 122,
#  'diarrhea': 2,
#  'disease1': 57,
#  'disease10': 100,
#  'disease11': 63,
#  'disease12': 119,
#  'disease13': 241,
#  'disease14': 179,
#  'disease15': 116,
#  'disease16': 124,
#  'disease17': 138,
#  'disease18': 22,
#  'disease19': 47,
#  'disease2': 105,
#  'disease20': 24,
#  'disease21': 77,
#  'disease22': 226,
#  'disease23': 184,
#  'disease24': 125,
#  'disease25': 151,
#  'disease26': 141,
#  'disease27': 145,
#  'disease28': 152,
#  'disease29': 95,
#  'disease3': 173,
#  'disease30': 186,
#  'disease31': 232,
#  'disease32': 121,
#  'disease33': 8,
#  'disease34': 33,
#  'disease35': 215,
#  'disease36': 101,
#  'disease37': 53,
#  'disease38': 129,
#  'disease39': 185,
#  'disease4': 108,
#  'disease40': 107,
#  'disease41': 94,
#  'disease42': 136,
#  'disease43': 91,
#  'disease44': 146,
#  'disease45': 178,
#  'disease46': 147,
#  'disease47': 103,
#  'disease48': 15,
#  'disease49': 130,
#  'disease5': 137,
#  'disease50': 12,
#  'disease51': 13,
#  'disease52': 189,
#  'disease53': 6,
#  'disease54': 42,
#  'disease55': 61,
#  'disease56': 92,
#  'disease57': 131,
#  'disease58': 44,
#  'disease59': 104,
#  'disease6': 229,
#  'disease60': 30,
#  'disease61': 201,
#  'disease62': 49,
#  'disease63': 207,
#  'disease64': 208,
#  'disease65': 5,
#  'disease66': 72,
#  'disease67': 140,
#  'disease68': 20,
#  'disease69': 83,
#  'disease7': 194,
#  'disease70': 27,
#  'disease71': 216,
#  'disease72': 180,
#  'disease73': 21,
#  'disease74': 148,
#  'disease75': 97,
#  'disease76': 182,
#  'disease77': 187,
#  'disease78': 82,
#  'disease79': 132,
#  'disease8': 26,
#  'disease80': 45,
#  'disease81': 217,
#  'disease82': 181,
#  'disease83': 170,
#  'disease84': 204,
#  'disease85': 51,
#  'disease86': 18,
#  'disease87': 195,
#  'disease9': 123,
#  'distancing': 233,
#  'donate': 230,
#  'drive': 39,
#  'drowning': 115,
#  'eu': 190,
#  'europe': 112,
#  'europecovid': 17,
#  'eyeinjury': 84,
#  'faces': 172,
#  'fainting': 127,
#  'family': 211,
#  'fever': 1,
#  'fluvaccine': 117,
#  'food': 165,
#  'fracture': 7,
#  'friends': 67,
#  'frostbite': 3,
#  'functions': 106,
#  'gastrointestinalproblems': 236,
#  'government': 70,
#  'greetings': 55,
#  'headache': 128,
#  'headinjury': 228,
#  'heatexhaustion': 56,
#  'heatstroke': 221,
#  'home': 169,
#  'house': 163,
#  'ibuprofen': 118,
#  'illness': 29,
#  'incubarion': 219,
#  'incubation': 43,
#  'incubationcorona': 40,
#  'infection': 238,
#  'infectious': 52,
#  'information': 28,
#  'insectbites': 113,
#  'intercollegiate': 188,
#  'isolate': 87,
#  'labour': 168,
#  'lung': 235,
#  'mask': 120,
#  'maskcovid': 110,
#  'measure': 111,
#  'medical': 96,
#  'medicalappointment': 142,
#  'medicine': 223,
#  'mosquitoes': 90,
#  'nasalcongestion': 37,
#  'normalbleeding': 213,
#  'nosebleed': 10,
#  'notdo': 23,
#  'package': 177,
#  'park': 19,
#  'peak': 134,
#  'pet': 93,
#  'pets': 222,
#  'poison': 73,
#  'pregnant': 206,
#  'prevent': 224,
#  'protect': 154,
#  'pulledmuscle': 99,
#  'rash': 218,
#  'rectalbleeding': 76,
#  'reduceinfection': 210,
#  'relatives': 158,
#  'restriction': 202,
#  'rise': 197,
#  'risk': 62,
#  'riskcorona': 133,
#  'riskpregnant': 80,
#  'risktransmission': 231,
#  'rules': 114,
#  'safe': 149,
#  'sanitizer': 150,
#  'sars': 153,
#  'schools': 16,
#  'second': 205,
#  'seizure': 14,
#  'sick': 36,
#  'skinproblems': 144,
#  'smoke': 135,
#  'snakebite': 102,
#  'sorethroat': 203,
#  'splinter': 81,
#  'sprains': 48,
#  'spread': 243,
#  'stigma': 65,
#  'stings': 220,
#  'strains': 175,
#  'sunburn': 161,
#  'symptoms': 34,
#  'symptomscorona': 54,
#  'teaching': 225,
#  'teeth': 167,
#  'temperature': 200,
#  'test': 198,
#  'testcovid': 237,
#  'testdoctor': 159,
#  'testiclepain': 79,
#  'testing': 50,
#  'transmissioncorona': 4,
#  'transmitted': 212,
#  'travel': 157,
#  'treatment': 25,
#  'treatmentcorona': 35,
#  'useofmask': 143,
#  'vaccine': 166,
#  'vertigo': 234,
#  'virus': 242,
#  'vulnerable': 58,
#  'weather': 86,
#  'who': 171,
#  'work': 156,
#  'workerhome': 41,
#  'workerrisk': 46,
#  'worry': 192,
#  'worrycovid': 176,
#  'wound': 38}

# %%
encoded_output = encoding_doc(output_tokenizer, intent)

# %%
encoded_output = np.array(encoded_output).reshape(len(encoded_output), 1)

# %%
encoded_output.shape
# Out:
# (810, 1)

# %%
def one_hot(encode):
    
#     label_encoder = preprocessing.LabelEncoder() 
#     return label_encoder.fit_transform(encode) 
    
    o = OneHotEncoder(sparse = False)
    return(o.fit_transform(encode))

# %%
output_one_hot = one_hot(encoded_output)

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, val_X, train_Y, val_Y = train_test_split(padded_doc, output_one_hot, test_size = 0.2)

# %%
print("Shape of train_X = %s and train_Y = %s" % (train_X.shape, train_Y.shape))
print("Shape of val_X = %s and val_Y = %s" % (val_X.shape, val_Y.shape))

# Shape of train_X = (164, 17) and train_Y = (164, 2)
# Shape of val_X = (42, 17) and val_Y = (42, 2)
# Out:
# Shape of train_X = (648, 40) and train_Y = (648, 243)
# Shape of val_X = (162, 40) and val_Y = (162, 243)

# %%
import tensorflow as tf

# %%
units=256

# %%
from keras.layers import Conv2D

# %%
# model = Sequential()
# model.add(Embedding(vocab_size, 128, input_length = max_length, trainable = False))
# model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
# model.add(MaxPooling1D(pool_size=2))
# model.add(LSTM(100))
# model.add(Dense(2, activation='softmax'))
# optimizer = tf.keras.optimizers.Adam(lr=1e-3)

model = Sequential()
model.add(Embedding(vocab_size, 128, input_length = max_length, trainable = False))
model.add(Dropout(0.15))
model.add(Conv1D(5, kernel_size = 3, activation = 'relu'))
model.add(Dropout(0.15))
model.add(Conv1D(4, kernel_size = 2, activation = 'relu'))
model.add(Flatten())
model.add(Dense(243, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 40, 128)           118656
#
#  dropout_10 (Dropout)        (None, 40, 128)           0
#
#  conv1d_14 (Conv1D)          (None, 38, 5)             1925
#
#  dropout_11 (Dropout)        (None, 38, 5)             0
#
#  conv1d_15 (Conv1D)          (None, 37, 4)             44
#
#  flatten_4 (Flatten)         (None, 148)               0
#
#  dense_3 (Dense)             (None, 243)               36207
#
# =================================================================
# Total params: 156,832
# Trainable params: 38,176
# Non-trainable params: 118,656
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from keras.callbacks import History
history = History()

# %%
m = model.fit(train_X, train_Y, validation_data = (val_X, val_Y),
                   epochs = 50, batch_size = 5, callbacks = [history])
# Out:
# Epoch 1/50
# 130/130 [==============================] - 2s 10ms/step - loss: 5.4841 - accuracy: 0.0123 - val_loss: 5.4925 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 130/130 [==============================] - 1s 8ms/step - loss: 5.2839 - accuracy: 0.0216 - val_loss: 5.5461 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 130/130 [==============================] - 1s 9ms/step - loss: 4.9534 - accuracy: 0.0509 - val_loss: 5.8592 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 130/130 [==============================] - 1s 8ms/step - loss: 4.5962 - accuracy: 0.0602 - val_loss: 5.8606 - val_accuracy: 0.0123
# Epoch 5/50
# 130/130 [==============================] - 1s 8ms/step - loss: 4.3304 - accuracy: 0.0725 - val_loss: 5.9858 - val_accuracy: 0.0370
# Epoch 6/50
# 130/130 [==============================] - 1s 8ms/step - loss: 4.0966 - accuracy: 0.0957 - val_loss: 5.9985 - val_accuracy: 0.0185
# Epoch 7/50
# 130/130 [==============================] - 1s 8ms/step - loss: 3.8954 - accuracy: 0.1157 - val_loss: 6.0778 - val_accuracy: 0.0556
# Epoch 8/50
# 130/130 [==============================] - 1s 8ms/step - loss: 3.7011 - accuracy: 0.1389 - val_loss: 6.1924 - val_accuracy: 0.0185
# Epoch 9/50
# 130/130 [==============================] - 1s 8ms/step - loss: 3.5002 - accuracy: 0.1559 - val_loss: 6.3496 - val_accuracy: 0.0309
# Epoch 10/50
# 130/130 [==============================] - 1s 8ms/step - loss: 3.3335 - accuracy: 0.1698 - val_loss: 6.4273 - val_accuracy: 0.0432
# Epoch 11/50
# 130/130 [==============================] - 1s 8ms/step - loss: 3.1604 - accuracy: 0.2160 - val_loss: 6.5203 - val_accuracy: 0.0741
# Epoch 12/50
# 130/130 [==============================] - 1s 8ms/step - loss: 2.9857 - accuracy: 0.2438 - val_loss: 6.7244 - val_accuracy: 0.0309
# Epoch 13/50
# 130/130 [==============================] - 1s 8ms/step - loss: 2.8640 - accuracy: 0.2731 - val_loss: 6.8770 - val_accuracy: 0.0864
# Epoch 14/50
# 130/130 [==============================] - 1s 8ms/step - loss: 2.7659 - accuracy: 0.2762 - val_loss: 6.9840 - val_accuracy: 0.0556
# Epoch 15/50
# 130/130 [==============================] - 1s 8ms/step - loss: 2.6799 - accuracy: 0.2886 - val_loss: 7.0543 - val_accuracy: 0.0864
# Epoch 16/50
# 130/130 [==============================] - 1s 8ms/step - loss: 2.5783 - accuracy: 0.3133 - val_loss: 7.1695 - val_accuracy: 0.0988
# Epoch 17/50
# 130/130 [==============================] - 1s 9ms/step - loss: 2.4893 - accuracy: 0.3519 - val_loss: 7.2947 - val_accuracy: 0.0617
# Epoch 18/50
# 130/130 [==============================] - 1s 8ms/step - loss: 2.3924 - accuracy: 0.3627 - val_loss: 7.3597 - val_accuracy: 0.0679
# Epoch 19/50
# 130/130 [==============================] - 1s 8ms/step - loss: 2.2964 - accuracy: 0.4105 - val_loss: 7.5194 - val_accuracy: 0.0617
# Epoch 20/50
# 130/130 [==============================] - 1s 8ms/step - loss: 2.2557 - accuracy: 0.3966 - val_loss: 7.6232 - val_accuracy: 0.0741
# Epoch 21/50
# 130/130 [==============================] - 1s 8ms/step - loss: 2.1931 - accuracy: 0.3873 - val_loss: 7.7649 - val_accuracy: 0.0802
# Epoch 22/50
# 130/130 [==============================] - 1s 8ms/step - loss: 2.1474 - accuracy: 0.3951 - val_loss: 7.9064 - val_accuracy: 0.0864
# Epoch 23/50
# 130/130 [==============================] - 1s 8ms/step - loss: 2.0789 - accuracy: 0.4244 - val_loss: 8.0079 - val_accuracy: 0.0802
# Epoch 24/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.9860 - accuracy: 0.4660 - val_loss: 8.1937 - val_accuracy: 0.0802
# Epoch 25/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.9752 - accuracy: 0.4769 - val_loss: 8.0811 - val_accuracy: 0.1235
# Epoch 26/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.8991 - accuracy: 0.4861 - val_loss: 8.2737 - val_accuracy: 0.1049
# Epoch 27/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.8785 - accuracy: 0.4907 - val_loss: 8.3531 - val_accuracy: 0.1111
# Epoch 28/50
# 130/130 [==============================] - 1s 7ms/step - loss: 1.7910 - accuracy: 0.5093 - val_loss: 8.4593 - val_accuracy: 0.1173
# Epoch 29/50
# 130/130 [==============================] - 1s 7ms/step - loss: 1.7943 - accuracy: 0.4938 - val_loss: 8.5166 - val_accuracy: 0.1358
# Epoch 30/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.7204 - accuracy: 0.5293 - val_loss: 8.7525 - val_accuracy: 0.1049
# Epoch 31/50
# 130/130 [==============================] - 1s 7ms/step - loss: 1.7426 - accuracy: 0.5108 - val_loss: 8.6588 - val_accuracy: 0.1296
# Epoch 32/50
# 130/130 [==============================] - 1s 7ms/step - loss: 1.7391 - accuracy: 0.5185 - val_loss: 8.7261 - val_accuracy: 0.1296
# Epoch 33/50
# 130/130 [==============================] - 1s 7ms/step - loss: 1.6707 - accuracy: 0.5309 - val_loss: 8.7959 - val_accuracy: 0.1235
# Epoch 34/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.6247 - accuracy: 0.5293 - val_loss: 9.0438 - val_accuracy: 0.1235
# Epoch 35/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.5666 - accuracy: 0.5802 - val_loss: 9.0433 - val_accuracy: 0.1296
# Epoch 36/50
# 130/130 [==============================] - 1s 7ms/step - loss: 1.5587 - accuracy: 0.5741 - val_loss: 9.1258 - val_accuracy: 0.1173
# Epoch 37/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.5751 - accuracy: 0.5664 - val_loss: 9.2540 - val_accuracy: 0.1173
# Epoch 38/50
# 130/130 [==============================] - 1s 7ms/step - loss: 1.4948 - accuracy: 0.5880 - val_loss: 9.3314 - val_accuracy: 0.1235
# Epoch 39/50
# 130/130 [==============================] - 1s 7ms/step - loss: 1.4578 - accuracy: 0.5988 - val_loss: 9.4278 - val_accuracy: 0.1235
# Epoch 40/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.4760 - accuracy: 0.5741 - val_loss: 9.4566 - val_accuracy: 0.1235
# Epoch 41/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.4230 - accuracy: 0.5972 - val_loss: 9.5140 - val_accuracy: 0.1358
# Epoch 42/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.4705 - accuracy: 0.5910 - val_loss: 9.5528 - val_accuracy: 0.1296
# Epoch 43/50
# 130/130 [==============================] - 1s 7ms/step - loss: 1.4396 - accuracy: 0.5818 - val_loss: 9.6102 - val_accuracy: 0.1049
# Epoch 44/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.3638 - accuracy: 0.6281 - val_loss: 9.6393 - val_accuracy: 0.1358
# Epoch 45/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.3539 - accuracy: 0.6157 - val_loss: 9.7170 - val_accuracy: 0.1296
# Epoch 46/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.2973 - accuracy: 0.6543 - val_loss: 9.8310 - val_accuracy: 0.1543
# Epoch 47/50
# 130/130 [==============================] - 1s 9ms/step - loss: 1.2974 - accuracy: 0.6265 - val_loss: 9.9208 - val_accuracy: 0.1049
# Epoch 48/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.2842 - accuracy: 0.6173 - val_loss: 9.9407 - val_accuracy: 0.1420
# Epoch 49/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.2536 - accuracy: 0.6590 - val_loss: 10.0301 - val_accuracy: 0.1296
# Epoch 50/50
# 130/130 [==============================] - 1s 8ms/step - loss: 1.2134 - accuracy: 0.6590 - val_loss: 10.1399 - val_accuracy: 0.1173

# %%
plt.plot(m.history['accuracy'])
plt.plot(m.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()

plt.plot(m.history['loss'])
plt.plot(m.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
